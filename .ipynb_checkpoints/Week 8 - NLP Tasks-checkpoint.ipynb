# %% [markdown]
# # Import Important Libraries

# %%
import requests
from bs4 import BeautifulSoup
import gensim

# %%
url = 'https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause'

# %%
page = requests.get(url).text

# %%
soup = BeautifulSoup(page)

# %%
header = soup.find('h1').get_text()

# %%
date = soup.find('span', attrs = {'class': 'date'}).text
date

# %%
p_tags = soup.find_all('p')

# %%
text = [tags.get_text().strip() for tags in p_tags]

# %%
print (text)

# %%
sentence_list = [sentence for sentence in text if not '\n' in sentence]

# %%
sentence_list = [sentence for sentence in sentence_list if '.' in sentence]

# %%
article = ''.join(sentence_list)
article

# %%
import docx

# %%
doc = docx.Document()

# %%
doc.add_heading(header)

# %%
doc.add_picture('img.png')

# %%
doc.add_paragraph(date)

# %%
doc.add_paragraph(article)

# %%
doc.save('document.docx')

# %% [markdown]
# # Class Task

# %%
url2 = 'https://www.pau.edu.ng/news/professor-enase-resumes-as-the-deputy-vice-chancellor-of-pan-atlantic-university/'

# %%
page2 = requests.get(url2).text
page

# %%
soup2 = BeautifulSoup(page2)

# %%
header2 = soup2.find('h2').get_text()

# %%
p_tags2 = soup2.find_all('p')

# %%
text2 = [tags2.get_text().strip() for tags2 in p_tags2]

# %%
print (text2)

# %%
sentence_list2 = [sentence for sentence in text2 if not '\n' in sentence]

# %%
sentence_list2 = [sentence for sentence in sentence_list2 if '.' in sentence]

# %%
article2 = ''.join(sentence_list2)
article2

# %%
doc2 = docx.Document()

# %%
doc2.add_heading(header2)

# %%
doc2.add_picture('img2.jpg')

# %%
doc2.add_paragraph(article2)

# %%
doc2.save('document2.docx')

# %%
conda install -c conda-forge gensim

# %%
from gensim.summarization import summarize

# %%
summary = summarize(article, ratio=0.15)

# %%
d = docx.Document()

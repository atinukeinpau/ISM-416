# %% [markdown]
# # Import Important Libraries

# %%
import requests
from bs4 import BeautifulSoup
import gensim

# %%
from gensim.summarization import summarize

# %%
url = 'https://www.npr.org/2021/04/28/991683886/frightened-to-death-cheerleader-speech-case-gives-supreme-court-pause'

# %%
page = requests.get(url).text

# %%
soup = BeautifulSoup(page)

# %%
header = soup.find('h1').get_text()

# %%
date = soup.find('span', attrs = {'class': 'date'}).text
date
# Out:
# 'April 28, 2021'

# %%
p_tags = soup.find_all('p')

# %%
text = [tags.get_text().strip() for tags in p_tags]

# %%
print (text)
# Out:
# ['Nina Totenberg', 'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.\n                \n                \n                    \n                    Danna Singer/ACLU/AP\n                    \n                \nhide caption', 'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.', 'Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.', 'At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.', 'The case has been billed as the most important student speech case since 1969. That landmark ruling came at the height of the Vietnam War. Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.', 'By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.', "Wednesday's case did not involve such serious speech. It was brought by Brandi Levy, a 14-year-old high school cheerleader, who failed to win a promotion from the junior varsity cheer team to the varsity.", '"I was really upset and frustrated at everything," Levy explained in an NPR interview. So, that weekend, she posted a photo of herself and a friend flipping the bird to the camera, with the caption "F*** school F*** softball, F*** cheer, F*** everything."', "Brandi's post hit school like a small-town social media bomb; the school deemed the post disruptive to cheerleader morale and suspended her from the team for the rest of the year. The American Civil Liberties Union took her case to court, claiming that her free speech rights had been violated. And on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?", 'Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment. "If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing," he said.', 'Justice Sonia Sotomayor chimed in. "I\'m told by my law clerks that ... among a certain large percentage of the population, how much you curse is a badge of honor," she said. "Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others."', 'Justice Brett Kavanaugh, who coaches his daughters\' sports teams, seemed to understand Brandi\'s frustration, acknowledging that even NBA legend Michael Jordan had sore feelings more than 40 years after not making the varsity team in high school. As to this case, said Kavanaugh, "It didn\'t seem like the punishment was tailored to the offense. But how does that fit into the First Amendment Doctrine? Or does it at all?"', 'The argument illustrated just how hard that question is. Siding with the Mahanoy school district in the case, the Justice Department argued that schools could regulate off-campus speech only if it is related to school matters and could cause a "substantial disruption."', '"That means really everything that mentions a school at all is school speech, right?" asked a skeptical Justice Elena Kagan.', 'Deputy Solicitor General Malcolm Stewart tried to offer a nuanced distinction, but Kagan was having none of it. Cutting right to the question of which speech is punishable, she asked, "Can I give you a few hypotheticals, and you just tell me school speech or not school speech?"', '"The student emails his classmates the answer to the geometry homework every day after school?"',  ...

# %%
sentence_list = [sentence for sentence in text if not '\n' in sentence]

# %%
sentence_list = [sentence for sentence in sentence_list if '.' in sentence]

# %%
article = ''.join(sentence_list)
article
# Out:
# 'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.The case has been billed as the most important student speech case since 1969. That landmark ruling came at the height of the Vietnam War. Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.Wednesday\'s case did not involve such serious speech. It was brought by Brandi Levy, a 14-year-old high school cheerleader, who failed to win a promotion from the junior varsity cheer team to the varsity."I was really upset and frustrated at everything," Levy explained in an NPR interview. So, that weekend, she posted a photo of herself and a friend flipping the bird to the camera, with the caption "F*** school F*** softball, F*** cheer, F*** everything."Brandi\'s post hit school like a small-town social media bomb; the school deemed the post disruptive to cheerleader morale and suspended her from the team for the rest of the year. The American Civil Liberties Union took her case to court, claiming that her free speech rights had been violated. And on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment. "If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing," he said.Justice Sonia Sotomayor chimed in. "I\'m told by my law clerks that ... among a certain large percentage of the population, how much you curse is a badge of honor," she said. "Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others."Justice Brett Kavanaugh, who coaches his daughters\' sports teams, seemed to understand Brandi\'s frustration, acknowledging that even NBA legend Michael Jordan had sore feelings more than 40 years after not making the varsity team in high school. As to this case, said Kavanaugh, "It didn\'t seem like the punishment was tailored to the offense. But how does that fit into the First Amendment Doctrine? Or does it at all?"The argument illustrated just how hard that question is. Siding with the Mahanoy school district in the case, the Justice Department argued that schools could regulate off-campus speech only if it is related to school matters and could cause a "substantial disruption.""That means really everything that mentions a school at all is school speech, right?" asked a skeptical Justice Elena Kagan.Deputy Solicitor General Malcolm Stewart tried to offer a nuanced distinction, but Kagan was having none of it. Cutting right to the question of which speech is punishable, she asked, "Can I give you a few hypotheticals, and you just tell me school speech or not school speech?"Each of these, conceded Stewart, would be considered school speech under the standard proposed by the Justice Department. In other words, all of these messages sent from off campus might well be punishable school speech.The ACLU\'s David Cole, representing Brandi Levy, said that once schools can discipline students for off-campus speech, that would dramatically expand the disciplinary reach of schools set out by the court in the Tinker case in 1969."Expanding Tinker would transform a li ...

# %%
summary = summarize(article, ratio=0.5)

# %%
import docx

# %%
doc = docx.Document()

# %%
doc.add_heading(header)

# %%
doc.add_picture('img.png')

# %%
doc.add_paragraph(date)

# %%
doc.add_paragraph(summary)

# %%
doc.save('document.docx')

# %%
summary
# Out:
# 'Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.The case has been billed as the most important student speech case since 1969.\nThat landmark ruling came at the height of the Vietnam War. Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.Wednesday\'s case did not involve such serious speech.\nAnd on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.\n"If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing," he said.Justice Sonia Sotomayor chimed in.\n"Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others."Justice Brett Kavanaugh, who coaches his daughters\' sports teams, seemed to understand Brandi\'s frustration, acknowledging that even NBA legend Michael Jordan had sore feelings more than 40 years after not making the varsity team in high school.\nSiding with the Mahanoy school district in the case, the Justice Department argued that schools could regulate off-campus speech only if it is related to school matters and could cause a "substantial disruption.""That means really everything that mentions a school at all is school speech, right?" asked a skeptical Justice Elena Kagan.Deputy Solicitor General Malcolm Stewart tried to offer a nuanced distinction, but Kagan was having none of it.\nCutting right to the question of which speech is punishable, she asked, "Can I give you a few hypotheticals, and you just tell me school speech or not school speech?"Each of these, conceded Stewart, would be considered school speech under the standard proposed by the Justice Department.\nIn other words, all of these messages sent from off campus might well be punishable school speech.The ACLU\'s David Cole, representing Brandi Levy, said that once schools can discipline students for off-campus speech, that would dramatically expand the disciplinary reach of schools set out by the court in the Tinker case in 1969."Expanding Tinker would transform a limited exception into a 24/7 rule that would upend the First Amendment\'s bedrock principle," argued Cole, "and would require students to effectively carry the schoolhouse on their backs in terms of speech rights everywhere they go."But, the justices wanted to know, what about cases of harassment and bullying?\nAfter all, some 47 states require enforcement of anti-bullying laws.Justice Kagan posited an off-campus website set up by high school boys to rank their female classmates appearance and sexual availability.\nAll of the justices probed repeatedly for workable standard to adopt — a rule that would guide schools as to how to handle these tricky questions.Cole said student speech should be protected online.\n"Outside of school, the priority is not to give the school discretion to regulate kids\' speech," he said.But the school district\'s lawyer, Lisa Blatt said that standard would be a "nightmare." It would, she said, mean "open season" on schools and produce "chaos" in the lower courts.'

# %% [markdown]
# # Tokenization

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(summary)

# %%
for token in doc:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# Brandi ---> None
# Levy ---> None
# wears ---> None
# her ---> None
# former ---> None
# cheerleading ---> None
# outfit ---> None
# as ---> None
# she ---> None
# looks ---> None
# at ---> None
# her ---> None
# mobile ---> None
# phone ---> None
# while ---> None
# sitting ---> None
# outside ---> None
# Mahanoy ---> None
# Area ---> None
# High ---> None
# School ---> None
# in ---> None
# Mahanoy ---> None
# City ---> None
# , ---> punctuation mark, comma
# Pa. ---> None
# , ---> punctuation mark, comma
# on ---> None
# April ---> None
# 4.Facing ---> None
# its ---> None
# biggest ---> None
# student ---> None
# speech ---> None
# case ---> case marking
# in ---> None
# a ---> None
# half ---> None
# - ---> None
# century ---> None
# , ---> punctuation mark, comma
# the ---> None
# Supreme ---> None
# Court ---> None
# seemed ---> None
# to ---> None
# be ---> None
# looking ---> None
# for ---> None
# a ---> None
# narrow ---> None
# exit ---> None
# door ---> None
# on ---> None
# Wednesday ---> None
# . ---> punctuation mark, sentence closer
# At ---> None
# issue ---> None
# was ---> None
# whether ---> None
# schools ---> None
# may ---> None
# punish ---> None
# students ---> None
# for ---> None
# speech ---> None
# that ---> None
# occurs ---> None
# online ---> None
# and ---> None
# off ---> None
# - ---> None
# campus ---> None
# but ---> None
# that ---> None
# may ---> None
# affect ---> None
# school ---> None
# order ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# case ---> case marking
# has ---> None
# been ---> None
# billed ---> None
# as ---> None
# the ---> None
# most ---> None
# important ---> None
# student ---> None
# speech ---> None
# case ---> case marking
# since ---> None
# 1969 ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# That ---> None
# landmark ---> None
# ruling ---> None
# came ---> None
# at ---> None
# the ---> None
# height ---> None
# of ---> None
# the ---> None
# Vietnam ---> None
# War ---> None
# . ---> punctuation mark, sentence closer
# Mary ---> None
# Beth ---> None
# Tinker ---> None
# and ---> None
# four ---> None
# other ---> None
# students ---> None
# went ---> None
# to ---> None
# court ---> None
# after ---> None
# they ---> None
# were ---> None
# suspended ---> None
# for ---> None
# wearing ---> None
# black ---> None
# armbands ---> None
# to ---> None
# school ---> None
# to ---> None
# protest ---> None
# the ---> None
# war ---> None
# . ---> punctuation mark, sentence closer
# By ---> None
# a ---> None
# vote ---> None
# of ---> None
# 7 ---> None
# to ---> None
# 2 ---> None
# , ---> punctuation mark, comma
# the ---> None
# high ---> None
# court ---> None
# ruled ---> None
# at ---> None
# the ---> None
# time ---> None
# for ---> None
# the ---> None
# first ---> None
# time ---> None
# that ---> None
# kids ---> None
# do ---> None
# have ---> None
# First ---> None
# Amendment ---> None
# free ---> None
# speech ---> None
# rights ---> None
# at ---> None
# school ---> None
# , ---> punctuation mark, comma
# unless ---> None
# school ---> None
# officials ---> None
# reasonably ---> None
# forecast ---> None
# it ---> None
# will ---> None
# cause ---> None
# disruptions ---> None
# . ---> punctuation mark, sentence closer
# Wednesday ---> None
# 's ---> None
# case ---> case marking
# did ---> None
# not ---> None
# involve ---> None
# such ---> None
# serious ---> None
# speech ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# And ---> None
# on ---> None
# Wednesday ---> None
# , ---> punctuation mark, comma
# the ---> None
# Supreme ---> None
# Court ---> None
# faced ---> None
# a ---> None
# question ---> None
# that ---> None
# did ---> None
# not ---> None
# exist ---> None
# in ---> None
# 1969 ---> None
# : ---> punctuation mark, colon or ellipsis
# Can ---> None
# schools ---> None
# punish ---> None
# students ---> None
# for ---> None
# their ---> None
# online ---> None
# but ---> None
# off ---> None
# - ---> None
# campus ---> None
# speech?Justice ---> None
# Stephen ---> None
# Breyer ---> None
# got ---> None
# to ---> None
# the ---> None
# heart ---> None
# of ---> None
# the ---> None
# matter ---> None
# quickly ---> None
# , ---> punctuation mark, comma
# wondering ---> None
# whether ---> None
# online ---> None
# swearing ---> None
# off ---> None
# - ---> None
# campus ---> None
# should ---> None
# even ---> None
# qualify ---> None
# for ---> None
# school ---> None
# punishment ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# " ---> None
# If ---> None
# swearing ---> None
# off ---> None
# - ---> None
# campus ---> None
# did ---> None
# [ ---> None
# qualify ---> None
# ] ---> None
# , ---> punctuation mark, comma
# my ---> None
# goodness ---> None
# , ---> punctuation mark, comma
# every ---> None
# school ---> None
# in ---> None
# the ---> None
# country ---> None
# would ---> None
# be ---> None
# doing ---> None
# nothing ---> None
# but ---> None
# punishing ---> None
# , ---> punctuation mark, comma
# " ---> None
# he ---> None
# said ---> None
# . ---> punctuation mark, sentence closer
# Justice ---> None
# Sonia ---> None
# Sotomayor ---> None
# chimed ---> None
# in ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# " ---> None
# Kids ---> None
# basically ---> None
# talk ---> None
# to ---> None
# classmates ---> None
# , ---> punctuation mark, comma
# most ---> None
# of ---> None
# their ---> None
# exchanges ---> None
# have ---> None
# to ---> None
# do ---> None
# with ---> None
# their ---> None
# perceptions ---> None
# of ---> None
# the ---> None
# authoritarian ---> None
# nature ---> None
# of ---> None
# their ---> None
# teachers ---> None
# and ---> None
# others ---> None
# . ---> punctuation mark, sentence closer
# "Justice ---> None
# Brett ---> None
# Kavanaugh ---> None
# , ---> punctuation mark, comma
# who ---> None
# coaches ---> None
# his ---> None
# daughters ---> None
# ' ---> None
# sports ---> None
# teams ---> None
# , ---> punctuation mark, comma
# seemed ---> None
# to ---> None
# understand ---> None
# Brandi ---> None
# 's ---> None
# frustration ---> None
# , ---> punctuation mark, comma
# acknowledging ---> None
# that ---> None
# even ---> None
# NBA ---> None
# legend ---> None
# Michael ---> None
# Jordan ---> None
# had ---> None
# sore ---> None
# feelings ---> None
# more ---> None
# than ---> None
# 40 ---> None
# years ---> None
# after ---> None
# not ---> None
# making ---> None
# the ---> None
# varsity ---> None
# team ---> None
# in ---> None
# high ---> None
# school ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Siding ---> None
# with ---> None
# the ---> None
# Mahanoy ---> None
# school ---> None
# district ---> None
# in ---> None
# the ---> None
# case ---> case marking
# , ---> punctuation mark, comma
# the ---> None
# Justice ---> None
# Department ---> None
# argued ---> None
# that ---> None
# schools ---> None
# could ---> None
# regulate ---> None
# off ---> None
# - ---> None
# campus ---> None
# speech ---> None
# only ---> None
# if ---> None
# it ---> None
# is ---> None
# related ---> None
# to ---> None
# school ---> None
# matters ---> None
# and ---> None
# could ---> None
# cause ---> None
# a ---> None
# " ---> None
# substantial ---> None
# disruption ---> None
# . ---> punctuation mark, sentence closer
# ""That ---> None
# means ---> None
# really ---> None
# everything ---> None
# that ---> None
# mentions ---> None
# a ---> None
# school ---> None
# at ---> None
# all ---> None
# is ---> None
# school ---> None
# speech ---> None
# , ---> punctuation mark, comma
# right ---> None
# ? ---> None
# " ---> None
# asked ---> None
# a ---> None
# skeptical ---> None
# Justice ---> None
# Elena ---> None
# Kagan ---> None
# . ---> punctuation mark, sentence closer
# Deputy ---> None
# Solicitor ---> None
# General ---> None
# Malcolm ---> None
# Stewart ---> None
# tried ---> None
# to ---> None
# offer ---> None
# a ---> None
# nuanced ---> None
# distinction ---> None
# , ---> punctuation mark, comma
# but ---> None
# Kagan ---> None
# was ---> None
# having ---> None
# none ---> None
# of ---> None
# it ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Cutting ---> None
# right ---> None
# to ---> None
# the ---> None
# question ---> None
# of ---> None
# which ---> None
# speech ---> None
# is ---> None
# punishable ---> None
# , ---> punctuation mark, comma
# she ---> None
# asked ---> None
# , ---> punctuation mark, comma
# " ---> None
# Can ---> None
# I ---> None
# give ---> None
# you ---> None
# a ---> None
# few ---> None
# hypotheticals ---> None
# , ---> punctuation mark, comma
# and ---> None
# you ---> None
# just ---> None
# tell ---> None
# me ---> None
# school ---> None
# speech ---> None
# or ---> None
# not ---> None
# school ---> None
# speech?"Each ---> None
# of ---> None
# these ---> None
# , ---> punctuation mark, comma
# conceded ---> None
# Stewart ---> None
# , ---> punctuation mark, comma
# would ---> None
# be ---> None
# considered ---> None
# school ---> None
# speech ---> None
# under ---> None
# the ---> None
# standard ---> None
# proposed ---> None
# by ---> None
# the ---> None
# Justice ---> None
# Department ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# In ---> None
# other ---> None
# words ---> None
# , ---> punctuation mark, comma
# all ---> None
# of ---> None
# these ---> None
# messages ---> None
# sent ---> None
# from ---> None
# off ---> None
# campus ---> None
# might ---> None
# well ---> None
# be ---> None
# punishable ---> None
# school ---> None
# speech ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# ACLU ---> None
# 's ---> None
# David ---> None
# Cole ---> None
# , ---> punctuation mark, comma
# representing ---> None
# Brandi ---> None
# Levy ---> None
# , ---> punctuation mark, comma
# said ---> None
# that ---> None
# once ---> None
# schools ---> None
# can ---> None
# discipline ---> None
# students ---> None
# for ---> None
# off ---> None
# - ---> None
# campus ---> None
# speech ---> None
# , ---> punctuation mark, comma
# that ---> None
# would ---> None
# dramatically ---> None
# expand ---> None
# the ---> None
# disciplinary ---> None
# reach ---> None
# of ---> None
# schools ---> None
# set ---> None
# out ---> None
# by ---> None
# the ---> None
# court ---> None
# in ---> None
# the ---> None
# Tinker ---> None
# case ---> case marking
# in ---> None
# 1969."Expanding ---> None
# Tinker ---> None
# would ---> None
# transform ---> None
# a ---> None
# limited ---> None
# exception ---> None
# into ---> None
# a ---> None
# 24/7 ---> None
# rule ---> None
# that ---> None
# would ---> None
# upend ---> None
# the ---> None
# First ---> None
# Amendment ---> None
# 's ---> None
# bedrock ---> None
# principle ---> None
# , ---> punctuation mark, comma
# " ---> None
# argued ---> None
# Cole ---> None
# , ---> punctuation mark, comma
# " ---> None
# and ---> None
# would ---> None
# require ---> None
# students ---> None
# to ---> None
# effectively ---> None
# carry ---> None
# the ---> None
# schoolhouse ---> None
# on ---> None
# their ---> None
# backs ---> None
# in ---> None
# terms ---> None
# of ---> None
# speech ---> None
# rights ---> None
# everywhere ---> None
# they ---> None
# go ---> None
# . ---> punctuation mark, sentence closer
# "But ---> None
# , ---> punctuation mark, comma
# the ---> None
# justices ---> None
# wanted ---> None
# to ---> None
# know ---> None
# , ---> punctuation mark, comma
# what ---> None
# about ---> None
# cases ---> None
# of ---> None
# harassment ---> None
# and ---> None
# bullying ---> None
# ? ---> None
#
#  ---> None
# After ---> None
# all ---> None
# , ---> punctuation mark, comma
# some ---> None
# 47 ---> None
# states ---> None
# require ---> None
# enforcement ---> None
# of ---> None
# anti ---> None
# - ---> None
# bullying ---> None
# laws ---> None
# . ---> punctuation mark, sentence closer
# Justice ---> None
# Kagan ---> None
# posited ---> None
# an ---> None
# off ---> None
# - ---> None
# campus ---> None
# website ---> None
# set ---> None
# up ---> None
# by ---> None
# high ---> None
# school ---> None
# boys ---> None
# to ---> None
# rank ---> None
# their ---> None
# female ---> None
# classmates ---> None
# appearance ---> None
# and ---> None
# sexual ---> None
# availability ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# All ---> None
# of ---> None
# the ---> None
# justices ---> None
# probed ---> None
# repeatedly ---> None
# for ---> None
# workable ---> None
# standard ---> None
# to ---> None
# adopt ---> None
# — ---> None
# a ---> None
# rule ---> None
# that ---> None
# would ---> None
# guide ---> None
# schools ---> None
# as ---> None
# to ---> None
# how ---> None
# to ---> None
# handle ---> None
# these ---> None
# tricky ---> None
# questions ---> None
# . ---> punctuation mark, sentence closer
# Cole ---> None
# said ---> None
# student ---> None
# speech ---> None
# should ---> None
# be ---> None
# protected ---> None
# online ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# " ---> None
# Outside ---> None
# of ---> None
# school ---> None
# , ---> punctuation mark, comma
# the ---> None
# priority ---> None
# is ---> None
# not ---> None
# to ---> None
# give ---> None
# the ---> None
# school ---> None
# discretion ---> None
# to ---> None
# regulate ---> None
# kids ---> None
# ' ---> None
# speech ---> None
# , ---> punctuation mark, comma
# " ---> None
# he ---> None
# said ---> None
# . ---> punctuation mark, sentence closer
# But ---> None
# the ---> None
# school ---> None
# district ---> None
# 's ---> None
# lawyer ---> None
# , ---> punctuation mark, comma
# Lisa ---> None
# Blatt ---> None
# said ---> None
# that ---> None
# standard ---> None
# would ---> None
# be ---> None
# a ---> None
# " ---> None
# nightmare ---> None
# . ---> punctuation mark, sentence closer
# " ---> None
# It ---> None
# would ---> None
# , ---> punctuation mark, comma
# she ---> None
# said ---> None
# , ---> punctuation mark, comma
# mean ---> None
# " ---> None
# open ---> None
# season ---> None
# " ---> None
# on ---> None
# schools ---> None
# and ---> None
# produce ---> None
# " ---> None
# chaos ---> None
# " ---> None
# in ---> None
# the ---> None
# lower ---> None
# courts ---> None
# . ---> punctuation mark, sentence closer

# %% [markdown]
# # POS Tagging

# %%
for token in doc:
    print(token.text, '--->', token.pos_, spacy.explain(token.pos_))
# Out:
# Brandi ---> PROPN proper noun
# Levy ---> PROPN proper noun
# wears ---> VERB verb
# her ---> PRON pronoun
# former ---> ADJ adjective
# cheerleading ---> NOUN noun
# outfit ---> NOUN noun
# as ---> ADP adposition
# she ---> PRON pronoun
# looks ---> VERB verb
# at ---> ADP adposition
# her ---> PRON pronoun
# mobile ---> ADJ adjective
# phone ---> NOUN noun
# while ---> SCONJ subordinating conjunction
# sitting ---> VERB verb
# outside ---> ADP adposition
# Mahanoy ---> PROPN proper noun
# Area ---> PROPN proper noun
# High ---> PROPN proper noun
# School ---> PROPN proper noun
# in ---> ADP adposition
# Mahanoy ---> PROPN proper noun
# City ---> PROPN proper noun
# , ---> PUNCT punctuation
# Pa. ---> PROPN proper noun
# , ---> PUNCT punctuation
# on ---> ADP adposition
# April ---> PROPN proper noun
# 4.Facing ---> NUM numeral
# its ---> PRON pronoun
# biggest ---> ADJ adjective
# student ---> NOUN noun
# speech ---> NOUN noun
# case ---> NOUN noun
# in ---> ADP adposition
# a ---> DET determiner
# half ---> ADJ adjective
# - ---> PUNCT punctuation
# century ---> NOUN noun
# , ---> PUNCT punctuation
# the ---> DET determiner
# Supreme ---> PROPN proper noun
# Court ---> PROPN proper noun
# seemed ---> VERB verb
# to ---> PART particle
# be ---> AUX auxiliary
# looking ---> VERB verb
# for ---> ADP adposition
# a ---> DET determiner
# narrow ---> ADJ adjective
# exit ---> NOUN noun
# door ---> NOUN noun
# on ---> ADP adposition
# Wednesday ---> PROPN proper noun
# . ---> PUNCT punctuation
# At ---> ADP adposition
# issue ---> NOUN noun
# was ---> AUX auxiliary
# whether ---> SCONJ subordinating conjunction
# schools ---> NOUN noun
# may ---> AUX auxiliary
# punish ---> VERB verb
# students ---> NOUN noun
# for ---> ADP adposition
# speech ---> NOUN noun
# that ---> DET determiner
# occurs ---> VERB verb
# online ---> ADV adverb
# and ---> CCONJ coordinating conjunction
# off ---> ADP adposition
# - ---> PUNCT punctuation
# campus ---> NOUN noun
# but ---> CCONJ coordinating conjunction
# that ---> DET determiner
# may ---> AUX auxiliary
# affect ---> VERB verb
# school ---> NOUN noun
# order ---> NOUN noun
# . ---> PUNCT punctuation
# The ---> DET determiner
# case ---> NOUN noun
# has ---> AUX auxiliary
# been ---> AUX auxiliary
# billed ---> VERB verb
# as ---> ADP adposition
# the ---> DET determiner
# most ---> ADV adverb
# important ---> ADJ adjective
# student ---> NOUN noun
# speech ---> NOUN noun
# case ---> NOUN noun
# since ---> SCONJ subordinating conjunction
# 1969 ---> NUM numeral
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# That ---> DET determiner
# landmark ---> NOUN noun
# ruling ---> NOUN noun
# came ---> VERB verb
# at ---> ADP adposition
# the ---> DET determiner
# height ---> NOUN noun
# of ---> ADP adposition
# the ---> DET determiner
# Vietnam ---> PROPN proper noun
# War ---> PROPN proper noun
# . ---> PUNCT punctuation
# Mary ---> PROPN proper noun
# Beth ---> PROPN proper noun
# Tinker ---> PROPN proper noun
# and ---> CCONJ coordinating conjunction
# four ---> NUM numeral
# other ---> ADJ adjective
# students ---> NOUN noun
# went ---> VERB verb
# to ---> ADP adposition
# court ---> NOUN noun
# after ---> ADP adposition
# they ---> PRON pronoun
# were ---> AUX auxiliary
# suspended ---> VERB verb
# for ---> ADP adposition
# wearing ---> VERB verb
# black ---> ADJ adjective
# armbands ---> NOUN noun
# to ---> ADP adposition
# school ---> NOUN noun
# to ---> PART particle
# protest ---> VERB verb
# the ---> DET determiner
# war ---> NOUN noun
# . ---> PUNCT punctuation
# By ---> ADP adposition
# a ---> DET determiner
# vote ---> NOUN noun
# of ---> ADP adposition
# 7 ---> NUM numeral
# to ---> ADP adposition
# 2 ---> NUM numeral
# , ---> PUNCT punctuation
# the ---> DET determiner
# high ---> ADJ adjective
# court ---> NOUN noun
# ruled ---> VERB verb
# at ---> ADP adposition
# the ---> DET determiner
# time ---> NOUN noun
# for ---> ADP adposition
# the ---> DET determiner
# first ---> ADJ adjective
# time ---> NOUN noun
# that ---> DET determiner
# kids ---> NOUN noun
# do ---> AUX auxiliary
# have ---> VERB verb
# First ---> PROPN proper noun
# Amendment ---> PROPN proper noun
# free ---> ADJ adjective
# speech ---> NOUN noun
# rights ---> NOUN noun
# at ---> ADP adposition
# school ---> NOUN noun
# , ---> PUNCT punctuation
# unless ---> SCONJ subordinating conjunction
# school ---> NOUN noun
# officials ---> NOUN noun
# reasonably ---> ADV adverb
# forecast ---> VERB verb
# it ---> PRON pronoun
# will ---> AUX auxiliary
# cause ---> VERB verb
# disruptions ---> NOUN noun
# . ---> PUNCT punctuation
# Wednesday ---> PROPN proper noun
# 's ---> PART particle
# case ---> NOUN noun
# did ---> AUX auxiliary
# not ---> PART particle
# involve ---> VERB verb
# such ---> ADJ adjective
# serious ---> ADJ adjective
# speech ---> NOUN noun
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# And ---> CCONJ coordinating conjunction
# on ---> ADP adposition
# Wednesday ---> PROPN proper noun
# , ---> PUNCT punctuation
# the ---> DET determiner
# Supreme ---> PROPN proper noun
# Court ---> PROPN proper noun
# faced ---> VERB verb
# a ---> DET determiner
# question ---> NOUN noun
# that ---> DET determiner
# did ---> AUX auxiliary
# not ---> PART particle
# exist ---> VERB verb
# in ---> ADP adposition
# 1969 ---> NUM numeral
# : ---> PUNCT punctuation
# Can ---> AUX auxiliary
# schools ---> NOUN noun
# punish ---> VERB verb
# students ---> NOUN noun
# for ---> ADP adposition
# their ---> PRON pronoun
# online ---> ADJ adjective
# but ---> CCONJ coordinating conjunction
# off ---> ADP adposition
# - ---> PUNCT punctuation
# campus ---> NOUN noun
# speech?Justice ---> NOUN noun
# Stephen ---> PROPN proper noun
# Breyer ---> PROPN proper noun
# got ---> VERB verb
# to ---> ADP adposition
# the ---> DET determiner
# heart ---> NOUN noun
# of ---> ADP adposition
# the ---> DET determiner
# matter ---> NOUN noun
# quickly ---> ADV adverb
# , ---> PUNCT punctuation
# wondering ---> VERB verb
# whether ---> SCONJ subordinating conjunction
# online ---> ADV adverb
# swearing ---> VERB verb
# off ---> ADP adposition
# - ---> PUNCT punctuation
# campus ---> NOUN noun
# should ---> AUX auxiliary
# even ---> ADV adverb
# qualify ---> VERB verb
# for ---> ADP adposition
# school ---> NOUN noun
# punishment ---> NOUN noun
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# " ---> PUNCT punctuation
# If ---> SCONJ subordinating conjunction
# swearing ---> VERB verb
# off ---> ADP adposition
# - ---> PUNCT punctuation
# campus ---> NOUN noun
# did ---> AUX auxiliary
# [ ---> PUNCT punctuation
# qualify ---> VERB verb
# ] ---> PUNCT punctuation
# , ---> PUNCT punctuation
# my ---> PRON pronoun
# goodness ---> NOUN noun
# , ---> PUNCT punctuation
# every ---> DET determiner
# school ---> NOUN noun
# in ---> ADP adposition
# the ---> DET determiner
# country ---> NOUN noun
# would ---> AUX auxiliary
# be ---> AUX auxiliary
# doing ---> VERB verb
# nothing ---> PRON pronoun
# but ---> CCONJ coordinating conjunction
# punishing ---> VERB verb
# , ---> PUNCT punctuation
# " ---> PUNCT punctuation
# he ---> PRON pronoun
# said ---> VERB verb
# . ---> PUNCT punctuation
# Justice ---> PROPN proper noun
# Sonia ---> PROPN proper noun
# Sotomayor ---> PROPN proper noun
# chimed ---> VERB verb
# in ---> ADP adposition
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# " ---> PUNCT punctuation
# Kids ---> NOUN noun
# basically ---> ADV adverb
# talk ---> VERB verb
# to ---> ADP adposition
# classmates ---> NOUN noun
# , ---> PUNCT punctuation
# most ---> ADJ adjective
# of ---> ADP adposition
# their ---> PRON pronoun
# exchanges ---> NOUN noun
# have ---> VERB verb
# to ---> PART particle
# do ---> VERB verb
# with ---> ADP adposition
# their ---> PRON pronoun
# perceptions ---> NOUN noun
# of ---> ADP adposition
# the ---> DET determiner
# authoritarian ---> ADJ adjective
# nature ---> NOUN noun
# of ---> ADP adposition
# their ---> PRON pronoun
# teachers ---> NOUN noun
# and ---> CCONJ coordinating conjunction
# others ---> NOUN noun
# . ---> PUNCT punctuation
# "Justice ---> VERB verb
# Brett ---> PROPN proper noun
# Kavanaugh ---> PROPN proper noun
# , ---> PUNCT punctuation
# who ---> PRON pronoun
# coaches ---> VERB verb
# his ---> PRON pronoun
# daughters ---> NOUN noun
# ' ---> PART particle
# sports ---> NOUN noun
# teams ---> NOUN noun
# , ---> PUNCT punctuation
# seemed ---> VERB verb
# to ---> PART particle
# understand ---> VERB verb
# Brandi ---> PROPN proper noun
# 's ---> PART particle
# frustration ---> NOUN noun
# , ---> PUNCT punctuation
# acknowledging ---> VERB verb
# that ---> SCONJ subordinating conjunction
# even ---> ADV adverb
# NBA ---> PROPN proper noun
# legend ---> NOUN noun
# Michael ---> PROPN proper noun
# Jordan ---> PROPN proper noun
# had ---> VERB verb
# sore ---> ADJ adjective
# feelings ---> NOUN noun
# more ---> ADJ adjective
# than ---> SCONJ subordinating conjunction
# 40 ---> NUM numeral
# years ---> NOUN noun
# after ---> ADP adposition
# not ---> PART particle
# making ---> VERB verb
# the ---> DET determiner
# varsity ---> NOUN noun
# team ---> NOUN noun
# in ---> ADP adposition
# high ---> ADJ adjective
# school ---> NOUN noun
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# Siding ---> VERB verb
# with ---> ADP adposition
# the ---> DET determiner
# Mahanoy ---> PROPN proper noun
# school ---> NOUN noun
# district ---> NOUN noun
# in ---> ADP adposition
# the ---> DET determiner
# case ---> NOUN noun
# , ---> PUNCT punctuation
# the ---> DET determiner
# Justice ---> PROPN proper noun
# Department ---> PROPN proper noun
# argued ---> VERB verb
# that ---> SCONJ subordinating conjunction
# schools ---> NOUN noun
# could ---> AUX auxiliary
# regulate ---> VERB verb
# off ---> ADP adposition
# - ---> PUNCT punctuation
# campus ---> NOUN noun
# speech ---> NOUN noun
# only ---> ADV adverb
# if ---> SCONJ subordinating conjunction
# it ---> PRON pronoun
# is ---> AUX auxiliary
# related ---> VERB verb
# to ---> ADP adposition
# school ---> NOUN noun
# matters ---> NOUN noun
# and ---> CCONJ coordinating conjunction
# could ---> AUX auxiliary
# cause ---> VERB verb
# a ---> DET determiner
# " ---> PUNCT punctuation
# substantial ---> ADJ adjective
# disruption ---> NOUN noun
# . ---> PUNCT punctuation
# ""That ---> DET determiner
# means ---> VERB verb
# really ---> ADV adverb
# everything ---> PRON pronoun
# that ---> DET determiner
# mentions ---> VERB verb
# a ---> DET determiner
# school ---> NOUN noun
# at ---> ADV adverb
# all ---> ADV adverb
# is ---> AUX auxiliary
# school ---> NOUN noun
# speech ---> NOUN noun
# , ---> PUNCT punctuation
# right ---> ADJ adjective
# ? ---> PUNCT punctuation
# " ---> PUNCT punctuation
# asked ---> VERB verb
# a ---> DET determiner
# skeptical ---> ADJ adjective
# Justice ---> PROPN proper noun
# Elena ---> PROPN proper noun
# Kagan ---> PROPN proper noun
# . ---> PUNCT punctuation
# Deputy ---> PROPN proper noun
# Solicitor ---> PROPN proper noun
# General ---> PROPN proper noun
# Malcolm ---> PROPN proper noun
# Stewart ---> PROPN proper noun
# tried ---> VERB verb
# to ---> PART particle
# offer ---> VERB verb
# a ---> DET determiner
# nuanced ---> VERB verb
# distinction ---> NOUN noun
# , ---> PUNCT punctuation
# but ---> CCONJ coordinating conjunction
# Kagan ---> PROPN proper noun
# was ---> AUX auxiliary
# having ---> VERB verb
# none ---> NOUN noun
# of ---> ADP adposition
# it ---> PRON pronoun
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# Cutting ---> VERB verb
# right ---> ADV adverb
# to ---> ADP adposition
# the ---> DET determiner
# question ---> NOUN noun
# of ---> ADP adposition
# which ---> DET determiner
# speech ---> NOUN noun
# is ---> VERB verb
# punishable ---> ADJ adjective
# , ---> PUNCT punctuation
# she ---> PRON pronoun
# asked ---> VERB verb
# , ---> PUNCT punctuation
# " ---> PUNCT punctuation
# Can ---> AUX auxiliary
# I ---> PRON pronoun
# give ---> VERB verb
# you ---> PRON pronoun
# a ---> DET determiner
# few ---> ADJ adjective
# hypotheticals ---> NOUN noun
# , ---> PUNCT punctuation
# and ---> CCONJ coordinating conjunction
# you ---> PRON pronoun
# just ---> ADV adverb
# tell ---> VERB verb
# me ---> PRON pronoun
# school ---> NOUN noun
# speech ---> NOUN noun
# or ---> CCONJ coordinating conjunction
# not ---> PART particle
# school ---> NOUN noun
# speech?"Each ---> NOUN noun
# of ---> ADP adposition
# these ---> DET determiner
# , ---> PUNCT punctuation
# conceded ---> VERB verb
# Stewart ---> PROPN proper noun
# , ---> PUNCT punctuation
# would ---> AUX auxiliary
# be ---> AUX auxiliary
# considered ---> VERB verb
# school ---> NOUN noun
# speech ---> NOUN noun
# under ---> ADP adposition
# the ---> DET determiner
# standard ---> NOUN noun
# proposed ---> VERB verb
# by ---> ADP adposition
# the ---> DET determiner
# Justice ---> PROPN proper noun
# Department ---> PROPN proper noun
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# In ---> ADP adposition
# other ---> ADJ adjective
# words ---> NOUN noun
# , ---> PUNCT punctuation
# all ---> DET determiner
# of ---> ADP adposition
# these ---> DET determiner
# messages ---> NOUN noun
# sent ---> VERB verb
# from ---> ADP adposition
# off ---> ADP adposition
# campus ---> NOUN noun
# might ---> AUX auxiliary
# well ---> ADV adverb
# be ---> VERB verb
# punishable ---> ADJ adjective
# school ---> NOUN noun
# speech ---> NOUN noun
# . ---> PUNCT punctuation
# The ---> DET determiner
# ACLU ---> PROPN proper noun
# 's ---> PART particle
# David ---> PROPN proper noun
# Cole ---> PROPN proper noun
# , ---> PUNCT punctuation
# representing ---> VERB verb
# Brandi ---> PROPN proper noun
# Levy ---> PROPN proper noun
# , ---> PUNCT punctuation
# said ---> VERB verb
# that ---> SCONJ subordinating conjunction
# once ---> SCONJ subordinating conjunction
# schools ---> NOUN noun
# can ---> AUX auxiliary
# discipline ---> VERB verb
# students ---> NOUN noun
# for ---> ADP adposition
# off ---> ADP adposition
# - ---> PUNCT punctuation
# campus ---> NOUN noun
# speech ---> NOUN noun
# , ---> PUNCT punctuation
# that ---> DET determiner
# would ---> AUX auxiliary
# dramatically ---> ADV adverb
# expand ---> VERB verb
# the ---> DET determiner
# disciplinary ---> ADJ adjective
# reach ---> NOUN noun
# of ---> ADP adposition
# schools ---> NOUN noun
# set ---> VERB verb
# out ---> ADP adposition
# by ---> ADP adposition
# the ---> DET determiner
# court ---> NOUN noun
# in ---> ADP adposition
# the ---> DET determiner
# Tinker ---> PROPN proper noun
# case ---> NOUN noun
# in ---> ADP adposition
# 1969."Expanding ---> VERB verb
# Tinker ---> PROPN proper noun
# would ---> AUX auxiliary
# transform ---> VERB verb
# a ---> DET determiner
# limited ---> ADJ adjective
# exception ---> NOUN noun
# into ---> ADP adposition
# a ---> DET determiner
# 24/7 ---> NUM numeral
# rule ---> NOUN noun
# that ---> DET determiner
# would ---> AUX auxiliary
# upend ---> VERB verb
# the ---> DET determiner
# First ---> PROPN proper noun
# Amendment ---> PROPN proper noun
# 's ---> PART particle
# bedrock ---> NOUN noun
# principle ---> NOUN noun
# , ---> PUNCT punctuation
# " ---> PUNCT punctuation
# argued ---> VERB verb
# Cole ---> PROPN proper noun
# , ---> PUNCT punctuation
# " ---> PUNCT punctuation
# and ---> CCONJ coordinating conjunction
# would ---> AUX auxiliary
# require ---> VERB verb
# students ---> NOUN noun
# to ---> PART particle
# effectively ---> ADV adverb
# carry ---> VERB verb
# the ---> DET determiner
# schoolhouse ---> NOUN noun
# on ---> ADP adposition
# their ---> PRON pronoun
# backs ---> NOUN noun
# in ---> ADP adposition
# terms ---> NOUN noun
# of ---> ADP adposition
# speech ---> NOUN noun
# rights ---> NOUN noun
# everywhere ---> ADV adverb
# they ---> PRON pronoun
# go ---> VERB verb
# . ---> PUNCT punctuation
# "But ---> INTJ interjection
# , ---> PUNCT punctuation
# the ---> DET determiner
# justices ---> NOUN noun
# wanted ---> VERB verb
# to ---> PART particle
# know ---> VERB verb
# , ---> PUNCT punctuation
# what ---> PRON pronoun
# about ---> ADP adposition
# cases ---> NOUN noun
# of ---> ADP adposition
# harassment ---> NOUN noun
# and ---> CCONJ coordinating conjunction
# bullying ---> NOUN noun
# ? ---> PUNCT punctuation
#
#  ---> SPACE space
# After ---> ADV adverb
# all ---> ADV adverb
# , ---> PUNCT punctuation
# some ---> DET determiner
# 47 ---> NUM numeral
# states ---> NOUN noun
# require ---> VERB verb
# enforcement ---> NOUN noun
# of ---> ADP adposition
# anti ---> ADJ adjective
# - ---> ADJ adjective
# bullying ---> ADJ adjective
# laws ---> NOUN noun
# . ---> PUNCT punctuation
# Justice ---> PROPN proper noun
# Kagan ---> PROPN proper noun
# posited ---> VERB verb
# an ---> DET determiner
# off ---> ADJ adjective
# - ---> PUNCT punctuation
# campus ---> NOUN noun
# website ---> NOUN noun
# set ---> VERB verb
# up ---> ADP adposition
# by ---> ADP adposition
# high ---> ADJ adjective
# school ---> NOUN noun
# boys ---> NOUN noun
# to ---> PART particle
# rank ---> VERB verb
# their ---> PRON pronoun
# female ---> ADJ adjective
# classmates ---> NOUN noun
# appearance ---> NOUN noun
# and ---> CCONJ coordinating conjunction
# sexual ---> ADJ adjective
# availability ---> NOUN noun
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# All ---> DET determiner
# of ---> ADP adposition
# the ---> DET determiner
# justices ---> NOUN noun
# probed ---> VERB verb
# repeatedly ---> ADV adverb
# for ---> ADP adposition
# workable ---> ADJ adjective
# standard ---> NOUN noun
# to ---> PART particle
# adopt ---> VERB verb
# — ---> PUNCT punctuation
# a ---> DET determiner
# rule ---> NOUN noun
# that ---> DET determiner
# would ---> AUX auxiliary
# guide ---> VERB verb
# schools ---> NOUN noun
# as ---> ADP adposition
# to ---> ADP adposition
# how ---> ADV adverb
# to ---> PART particle
# handle ---> VERB verb
# these ---> DET determiner
# tricky ---> ADJ adjective
# questions ---> NOUN noun
# . ---> PUNCT punctuation
# Cole ---> PROPN proper noun
# said ---> VERB verb
# student ---> NOUN noun
# speech ---> NOUN noun
# should ---> AUX auxiliary
# be ---> AUX auxiliary
# protected ---> VERB verb
# online ---> ADV adverb
# . ---> PUNCT punctuation
#
#  ---> SPACE space
# " ---> PUNCT punctuation
# Outside ---> ADJ adjective
# of ---> ADP adposition
# school ---> NOUN noun
# , ---> PUNCT punctuation
# the ---> DET determiner
# priority ---> NOUN noun
# is ---> AUX auxiliary
# not ---> PART particle
# to ---> PART particle
# give ---> VERB verb
# the ---> DET determiner
# school ---> NOUN noun
# discretion ---> NOUN noun
# to ---> PART particle
# regulate ---> VERB verb
# kids ---> NOUN noun
# ' ---> PART particle
# speech ---> NOUN noun
# , ---> PUNCT punctuation
# " ---> PUNCT punctuation
# he ---> PRON pronoun
# said ---> VERB verb
# . ---> PUNCT punctuation
# But ---> CCONJ coordinating conjunction
# the ---> DET determiner
# school ---> NOUN noun
# district ---> NOUN noun
# 's ---> PART particle
# lawyer ---> NOUN noun
# , ---> PUNCT punctuation
# Lisa ---> PROPN proper noun
# Blatt ---> PROPN proper noun
# said ---> VERB verb
# that ---> SCONJ subordinating conjunction
# standard ---> NOUN noun
# would ---> AUX auxiliary
# be ---> VERB verb
# a ---> DET determiner
# " ---> PUNCT punctuation
# nightmare ---> NOUN noun
# . ---> PUNCT punctuation
# " ---> PUNCT punctuation
# It ---> PRON pronoun
# would ---> AUX auxiliary
# , ---> PUNCT punctuation
# she ---> PRON pronoun
# said ---> VERB verb
# , ---> PUNCT punctuation
# mean ---> VERB verb
# " ---> PUNCT punctuation
# open ---> ADJ adjective
# season ---> NOUN noun
# " ---> PUNCT punctuation
# on ---> ADP adposition
# schools ---> NOUN noun
# and ---> CCONJ coordinating conjunction
# produce ---> VERB verb
# " ---> PUNCT punctuation
# chaos ---> NOUN noun
# " ---> PUNCT punctuation
# in ---> ADP adposition
# the ---> DET determiner
# lower ---> ADJ adjective
# courts ---> NOUN noun
# . ---> PUNCT punctuation

# %% [markdown]
# # Depenency Parsing

# %%
for token in doc:
    print (token.text, '--->', token.dep_, spacy.explain(token.dep_))
# Out:
# Brandi ---> compound compound
# Levy ---> nsubj nominal subject
# wears ---> ROOT None
# her ---> poss possession modifier
# former ---> amod adjectival modifier
# cheerleading ---> compound compound
# outfit ---> dobj direct object
# as ---> mark marker
# she ---> nsubj nominal subject
# looks ---> advcl adverbial clause modifier
# at ---> prep prepositional modifier
# her ---> poss possession modifier
# mobile ---> amod adjectival modifier
# phone ---> pobj object of preposition
# while ---> mark marker
# sitting ---> advcl adverbial clause modifier
# outside ---> prep prepositional modifier
# Mahanoy ---> compound compound
# Area ---> compound compound
# High ---> compound compound
# School ---> pobj object of preposition
# in ---> prep prepositional modifier
# Mahanoy ---> compound compound
# City ---> pobj object of preposition
# , ---> punct punctuation
# Pa. ---> appos appositional modifier
# , ---> punct punctuation
# on ---> prep prepositional modifier
# April ---> pobj object of preposition
# 4.Facing ---> nummod numeric modifier
# its ---> poss possession modifier
# biggest ---> amod adjectival modifier
# student ---> compound compound
# speech ---> compound compound
# case ---> pobj object of preposition
# in ---> prep prepositional modifier
# a ---> det determiner
# half ---> amod adjectival modifier
# - ---> punct punctuation
# century ---> pobj object of preposition
# , ---> punct punctuation
# the ---> det determiner
# Supreme ---> compound compound
# Court ---> nsubj nominal subject
# seemed ---> conj conjunct
# to ---> aux auxiliary
# be ---> aux auxiliary
# looking ---> xcomp open clausal complement
# for ---> prep prepositional modifier
# a ---> det determiner
# narrow ---> amod adjectival modifier
# exit ---> compound compound
# door ---> pobj object of preposition
# on ---> prep prepositional modifier
# Wednesday ---> pobj object of preposition
# . ---> punct punctuation
# At ---> prep prepositional modifier
# issue ---> pobj object of preposition
# was ---> ROOT None
# whether ---> mark marker
# schools ---> nsubj nominal subject
# may ---> aux auxiliary
# punish ---> ccomp clausal complement
# students ---> dobj direct object
# for ---> prep prepositional modifier
# speech ---> pobj object of preposition
# that ---> nsubj nominal subject
# occurs ---> relcl relative clause modifier
# online ---> advmod adverbial modifier
# and ---> cc coordinating conjunction
# off ---> conj conjunct
# - ---> punct punctuation
# campus ---> npadvmod noun phrase as adverbial modifier
# but ---> cc coordinating conjunction
# that ---> nsubj nominal subject
# may ---> aux auxiliary
# affect ---> conj conjunct
# school ---> compound compound
# order ---> dobj direct object
# . ---> punct punctuation
# The ---> det determiner
# case ---> nsubjpass nominal subject (passive)
# has ---> aux auxiliary
# been ---> auxpass auxiliary (passive)
# billed ---> ROOT None
# as ---> prep prepositional modifier
# the ---> det determiner
# most ---> advmod adverbial modifier
# important ---> amod adjectival modifier
# student ---> compound compound
# speech ---> compound compound
# case ---> pobj object of preposition
# since ---> prep prepositional modifier
# 1969 ---> pobj object of preposition
# . ---> punct punctuation
#
#  ---> ROOT None
# That ---> det determiner
# landmark ---> compound compound
# ruling ---> nsubj nominal subject
# came ---> ROOT None
# at ---> prep prepositional modifier
# the ---> det determiner
# height ---> pobj object of preposition
# of ---> prep prepositional modifier
# the ---> det determiner
# Vietnam ---> compound compound
# War ---> pobj object of preposition
# . ---> punct punctuation
# Mary ---> compound compound
# Beth ---> compound compound
# Tinker ---> nsubj nominal subject
# and ---> cc coordinating conjunction
# four ---> nummod numeric modifier
# other ---> amod adjectival modifier
# students ---> conj conjunct
# went ---> ROOT None
# to ---> prep prepositional modifier
# court ---> pobj object of preposition
# after ---> mark marker
# they ---> nsubjpass nominal subject (passive)
# were ---> auxpass auxiliary (passive)
# suspended ---> advcl adverbial clause modifier
# for ---> prep prepositional modifier
# wearing ---> pcomp complement of preposition
# black ---> amod adjectival modifier
# armbands ---> dobj direct object
# to ---> prep prepositional modifier
# school ---> pobj object of preposition
# to ---> aux auxiliary
# protest ---> advcl adverbial clause modifier
# the ---> det determiner
# war ---> dobj direct object
# . ---> punct punctuation
# By ---> prep prepositional modifier
# a ---> det determiner
# vote ---> pobj object of preposition
# of ---> prep prepositional modifier
# 7 ---> quantmod modifier of quantifier
# to ---> quantmod modifier of quantifier
# 2 ---> pobj object of preposition
# , ---> punct punctuation
# the ---> det determiner
# high ---> amod adjectival modifier
# court ---> nsubj nominal subject
# ruled ---> ROOT None
# at ---> prep prepositional modifier
# the ---> det determiner
# time ---> pobj object of preposition
# for ---> prep prepositional modifier
# the ---> det determiner
# first ---> amod adjectival modifier
# time ---> pobj object of preposition
# that ---> advmod adverbial modifier
# kids ---> nsubj nominal subject
# do ---> aux auxiliary
# have ---> relcl relative clause modifier
# First ---> nmod modifier of nominal
# Amendment ---> nmod modifier of nominal
# free ---> amod adjectival modifier
# speech ---> compound compound
# rights ---> dobj direct object
# at ---> prep prepositional modifier
# school ---> pobj object of preposition
# , ---> punct punctuation
# unless ---> mark marker
# school ---> compound compound
# officials ---> nsubj nominal subject
# reasonably ---> advmod adverbial modifier
# forecast ---> advcl adverbial clause modifier
# it ---> nsubj nominal subject
# will ---> aux auxiliary
# cause ---> ccomp clausal complement
# disruptions ---> dobj direct object
# . ---> punct punctuation
# Wednesday ---> poss possession modifier
# 's ---> case case marking
# case ---> nsubj nominal subject
# did ---> aux auxiliary
# not ---> neg negation modifier
# involve ---> ROOT None
# such ---> amod adjectival modifier
# serious ---> amod adjectival modifier
# speech ---> dobj direct object
# . ---> punct punctuation
#
#  ---> ROOT None
# And ---> cc coordinating conjunction
# on ---> prep prepositional modifier
# Wednesday ---> pobj object of preposition
# , ---> punct punctuation
# the ---> det determiner
# Supreme ---> compound compound
# Court ---> nsubj nominal subject
# faced ---> ccomp clausal complement
# a ---> det determiner
# question ---> dobj direct object
# that ---> nsubj nominal subject
# did ---> aux auxiliary
# not ---> neg negation modifier
# exist ---> relcl relative clause modifier
# in ---> prep prepositional modifier
# 1969 ---> pobj object of preposition
# : ---> punct punctuation
# Can ---> aux auxiliary
# schools ---> nsubj nominal subject
# punish ---> ROOT None
# students ---> dobj direct object
# for ---> prep prepositional modifier
# their ---> poss possession modifier
# online ---> amod adjectival modifier
# but ---> cc coordinating conjunction
# off ---> conj conjunct
# - ---> punct punctuation
# campus ---> compound compound
# speech?Justice ---> pobj object of preposition
# Stephen ---> compound compound
# Breyer ---> nsubj nominal subject
# got ---> advcl adverbial clause modifier
# to ---> prep prepositional modifier
# the ---> det determiner
# heart ---> pobj object of preposition
# of ---> prep prepositional modifier
# the ---> det determiner
# matter ---> pobj object of preposition
# quickly ---> advmod adverbial modifier
# , ---> punct punctuation
# wondering ---> advcl adverbial clause modifier
# whether ---> mark marker
# online ---> nsubj nominal subject
# swearing ---> nsubj nominal subject
# off ---> prt particle
# - ---> punct punctuation
# campus ---> dobj direct object
# should ---> aux auxiliary
# even ---> advmod adverbial modifier
# qualify ---> ccomp clausal complement
# for ---> prep prepositional modifier
# school ---> compound compound
# punishment ---> pobj object of preposition
# . ---> punct punctuation
#
#  ---> punct punctuation
# " ---> punct punctuation
# If ---> mark marker
# swearing ---> advcl adverbial clause modifier
# off ---> prt particle
# - ---> punct punctuation
# campus ---> dobj direct object
# did ---> aux auxiliary
# [ ---> punct punctuation
# qualify ---> advcl adverbial clause modifier
# ] ---> punct punctuation
# , ---> punct punctuation
# my ---> poss possession modifier
# goodness ---> npadvmod noun phrase as adverbial modifier
# , ---> punct punctuation
# every ---> det determiner
# school ---> nsubj nominal subject
# in ---> prep prepositional modifier
# the ---> det determiner
# country ---> pobj object of preposition
# would ---> aux auxiliary
# be ---> aux auxiliary
# doing ---> ccomp clausal complement
# nothing ---> dobj direct object
# but ---> prep prepositional modifier
# punishing ---> pobj object of preposition
# , ---> punct punctuation
# " ---> punct punctuation
# he ---> nsubj nominal subject
# said ---> ROOT None
# . ---> punct punctuation
# Justice ---> compound compound
# Sonia ---> compound compound
# Sotomayor ---> nsubj nominal subject
# chimed ---> ROOT None
# in ---> prt particle
# . ---> punct punctuation
#
#  ---> punct punctuation
# " ---> punct punctuation
# Kids ---> nsubj nominal subject
# basically ---> advmod adverbial modifier
# talk ---> ccomp clausal complement
# to ---> prep prepositional modifier
# classmates ---> pobj object of preposition
# , ---> punct punctuation
# most ---> nsubj nominal subject
# of ---> prep prepositional modifier
# their ---> poss possession modifier
# exchanges ---> pobj object of preposition
# have ---> ROOT None
# to ---> aux auxiliary
# do ---> xcomp open clausal complement
# with ---> prep prepositional modifier
# their ---> poss possession modifier
# perceptions ---> pobj object of preposition
# of ---> prep prepositional modifier
# the ---> det determiner
# authoritarian ---> amod adjectival modifier
# nature ---> pobj object of preposition
# of ---> prep prepositional modifier
# their ---> poss possession modifier
# teachers ---> pobj object of preposition
# and ---> cc coordinating conjunction
# others ---> conj conjunct
# . ---> punct punctuation
# "Justice ---> compound compound
# Brett ---> compound compound
# Kavanaugh ---> nsubj nominal subject
# , ---> punct punctuation
# who ---> nsubj nominal subject
# coaches ---> relcl relative clause modifier
# his ---> poss possession modifier
# daughters ---> poss possession modifier
# ' ---> case case marking
# sports ---> compound compound
# teams ---> dobj direct object
# , ---> punct punctuation
# seemed ---> ROOT None
# to ---> aux auxiliary
# understand ---> xcomp open clausal complement
# Brandi ---> poss possession modifier
# 's ---> case case marking
# frustration ---> dobj direct object
# , ---> punct punctuation
# acknowledging ---> advcl adverbial clause modifier
# that ---> mark marker
# even ---> advmod adverbial modifier
# NBA ---> compound compound
# legend ---> compound compound
# Michael ---> compound compound
# Jordan ---> nsubj nominal subject
# had ---> ccomp clausal complement
# sore ---> amod adjectival modifier
# feelings ---> dobj direct object
# more ---> amod adjectival modifier
# than ---> quantmod modifier of quantifier
# 40 ---> nummod numeric modifier
# years ---> npadvmod noun phrase as adverbial modifier
# after ---> prep prepositional modifier
# not ---> neg negation modifier
# making ---> pcomp complement of preposition
# the ---> det determiner
# varsity ---> compound compound
# team ---> dobj direct object
# in ---> prep prepositional modifier
# high ---> amod adjectival modifier
# school ---> pobj object of preposition
# . ---> punct punctuation
#
#  ---> ROOT None
# Siding ---> advcl adverbial clause modifier
# with ---> prep prepositional modifier
# the ---> det determiner
# Mahanoy ---> compound compound
# school ---> compound compound
# district ---> pobj object of preposition
# in ---> prep prepositional modifier
# the ---> det determiner
# case ---> pobj object of preposition
# , ---> punct punctuation
# the ---> det determiner
# Justice ---> compound compound
# Department ---> nsubj nominal subject
# argued ---> ROOT None
# that ---> mark marker
# schools ---> nsubj nominal subject
# could ---> aux auxiliary
# regulate ---> ccomp clausal complement
# off ---> nmod modifier of nominal
# - ---> punct punctuation
# campus ---> pobj object of preposition
# speech ---> dobj direct object
# only ---> advmod adverbial modifier
# if ---> mark marker
# it ---> nsubjpass nominal subject (passive)
# is ---> auxpass auxiliary (passive)
# related ---> advcl adverbial clause modifier
# to ---> prep prepositional modifier
# school ---> compound compound
# matters ---> pobj object of preposition
# and ---> cc coordinating conjunction
# could ---> aux auxiliary
# cause ---> conj conjunct
# a ---> det determiner
# " ---> punct punctuation
# substantial ---> amod adjectival modifier
# disruption ---> dobj direct object
# . ---> punct punctuation
# ""That ---> nsubj nominal subject
# means ---> ccomp clausal complement
# really ---> advmod adverbial modifier
# everything ---> dobj direct object
# that ---> nsubj nominal subject
# mentions ---> relcl relative clause modifier
# a ---> det determiner
# school ---> dobj direct object
# at ---> advmod adverbial modifier
# all ---> advmod adverbial modifier
# is ---> ccomp clausal complement
# school ---> compound compound
# speech ---> attr attribute
# , ---> punct punctuation
# right ---> advmod adverbial modifier
# ? ---> punct punctuation
# " ---> punct punctuation
# asked ---> ROOT None
# a ---> det determiner
# skeptical ---> amod adjectival modifier
# Justice ---> compound compound
# Elena ---> compound compound
# Kagan ---> dobj direct object
# . ---> punct punctuation
# Deputy ---> compound compound
# Solicitor ---> compound compound
# General ---> compound compound
# Malcolm ---> compound compound
# Stewart ---> nsubj nominal subject
# tried ---> ROOT None
# to ---> aux auxiliary
# offer ---> xcomp open clausal complement
# a ---> det determiner
# nuanced ---> amod adjectival modifier
# distinction ---> dobj direct object
# , ---> punct punctuation
# but ---> cc coordinating conjunction
# Kagan ---> nsubj nominal subject
# was ---> aux auxiliary
# having ---> conj conjunct
# none ---> dobj direct object
# of ---> prep prepositional modifier
# it ---> pobj object of preposition
# . ---> punct punctuation
#
#  ---> punct punctuation
# Cutting ---> advcl adverbial clause modifier
# right ---> dobj direct object
# to ---> prep prepositional modifier
# the ---> det determiner
# question ---> pobj object of preposition
# of ---> prep prepositional modifier
# which ---> det determiner
# speech ---> nsubj nominal subject
# is ---> pcomp complement of preposition
# punishable ---> acomp adjectival complement
# , ---> punct punctuation
# she ---> nsubj nominal subject
# asked ---> ROOT None
# , ---> punct punctuation
# " ---> punct punctuation
# Can ---> aux auxiliary
# I ---> nsubj nominal subject
# give ---> ccomp clausal complement
# you ---> dative dative
# a ---> quantmod modifier of quantifier
# few ---> amod adjectival modifier
# hypotheticals ---> dobj direct object
# , ---> punct punctuation
# and ---> cc coordinating conjunction
# you ---> nsubj nominal subject
# just ---> advmod adverbial modifier
# tell ---> conj conjunct
# me ---> dative dative
# school ---> compound compound
# speech ---> dobj direct object
# or ---> cc coordinating conjunction
# not ---> neg negation modifier
# school ---> conj conjunct
# speech?"Each ---> appos appositional modifier
# of ---> prep prepositional modifier
# these ---> pobj object of preposition
# , ---> punct punctuation
# conceded ---> xcomp open clausal complement
# Stewart ---> dobj direct object
# , ---> punct punctuation
# would ---> aux auxiliary
# be ---> auxpass auxiliary (passive)
# considered ---> ccomp clausal complement
# school ---> compound compound
# speech ---> oprd object predicate
# under ---> prep prepositional modifier
# the ---> det determiner
# standard ---> pobj object of preposition
# proposed ---> acl clausal modifier of noun (adjectival clause)
# by ---> agent agent
# the ---> det determiner
# Justice ---> compound compound
# Department ---> pobj object of preposition
# . ---> punct punctuation
#
#  ---> ROOT None
# In ---> prep prepositional modifier
# other ---> amod adjectival modifier
# words ---> pobj object of preposition
# , ---> punct punctuation
# all ---> nsubj nominal subject
# of ---> prep prepositional modifier
# these ---> det determiner
# messages ---> pobj object of preposition
# sent ---> acl clausal modifier of noun (adjectival clause)
# from ---> prep prepositional modifier
# off ---> prep prepositional modifier
# campus ---> pobj object of preposition
# might ---> aux auxiliary
# well ---> advmod adverbial modifier
# be ---> ROOT None
# punishable ---> amod adjectival modifier
# school ---> compound compound
# speech ---> attr attribute
# . ---> punct punctuation
# The ---> det determiner
# ACLU ---> poss possession modifier
# 's ---> case case marking
# David ---> compound compound
# Cole ---> nsubj nominal subject
# , ---> punct punctuation
# representing ---> acl clausal modifier of noun (adjectival clause)
# Brandi ---> compound compound
# Levy ---> dobj direct object
# , ---> punct punctuation
# said ---> ROOT None
# that ---> mark marker
# once ---> mark marker
# schools ---> nsubj nominal subject
# can ---> aux auxiliary
# discipline ---> advcl adverbial clause modifier
# students ---> dobj direct object
# for ---> prep prepositional modifier
# off ---> nmod modifier of nominal
# - ---> punct punctuation
# campus ---> pobj object of preposition
# speech ---> pobj object of preposition
# , ---> punct punctuation
# that ---> nsubj nominal subject
# would ---> aux auxiliary
# dramatically ---> advmod adverbial modifier
# expand ---> ccomp clausal complement
# the ---> det determiner
# disciplinary ---> amod adjectival modifier
# reach ---> dobj direct object
# of ---> prep prepositional modifier
# schools ---> pobj object of preposition
# set ---> acl clausal modifier of noun (adjectival clause)
# out ---> prt particle
# by ---> agent agent
# the ---> det determiner
# court ---> pobj object of preposition
# in ---> prep prepositional modifier
# the ---> det determiner
# Tinker ---> compound compound
# case ---> pobj object of preposition
# in ---> prep prepositional modifier
# 1969."Expanding ---> pcomp complement of preposition
# Tinker ---> nsubj nominal subject
# would ---> aux auxiliary
# transform ---> ccomp clausal complement
# a ---> det determiner
# limited ---> amod adjectival modifier
# exception ---> dobj direct object
# into ---> prep prepositional modifier
# a ---> det determiner
# 24/7 ---> nummod numeric modifier
# rule ---> pobj object of preposition
# that ---> nsubj nominal subject
# would ---> aux auxiliary
# upend ---> relcl relative clause modifier
# the ---> det determiner
# First ---> compound compound
# Amendment ---> poss possession modifier
# 's ---> case case marking
# bedrock ---> compound compound
# principle ---> dobj direct object
# , ---> punct punctuation
# " ---> punct punctuation
# argued ---> ccomp clausal complement
# Cole ---> nsubj nominal subject
# , ---> punct punctuation
# " ---> punct punctuation
# and ---> cc coordinating conjunction
# would ---> aux auxiliary
# require ---> conj conjunct
# students ---> dobj direct object
# to ---> aux auxiliary
# effectively ---> advmod adverbial modifier
# carry ---> xcomp open clausal complement
# the ---> det determiner
# schoolhouse ---> dobj direct object
# on ---> prep prepositional modifier
# their ---> poss possession modifier
# backs ---> pobj object of preposition
# in ---> prep prepositional modifier
# terms ---> pobj object of preposition
# of ---> prep prepositional modifier
# speech ---> compound compound
# rights ---> pobj object of preposition
# everywhere ---> advmod adverbial modifier
# they ---> nsubj nominal subject
# go ---> relcl relative clause modifier
# . ---> punct punctuation
# "But ---> intj interjection
# , ---> punct punctuation
# the ---> det determiner
# justices ---> nsubj nominal subject
# wanted ---> ROOT None
# to ---> aux auxiliary
# know ---> xcomp open clausal complement
# , ---> punct punctuation
# what ---> dep unclassified dependent
# about ---> prep prepositional modifier
# cases ---> pobj object of preposition
# of ---> prep prepositional modifier
# harassment ---> pobj object of preposition
# and ---> cc coordinating conjunction
# bullying ---> conj conjunct
# ? ---> punct punctuation
#
#  ---> punct punctuation
# After ---> advmod adverbial modifier
# all ---> advmod adverbial modifier
# , ---> punct punctuation
# some ---> quantmod modifier of quantifier
# 47 ---> nummod numeric modifier
# states ---> nsubj nominal subject
# require ---> ROOT None
# enforcement ---> dobj direct object
# of ---> prep prepositional modifier
# anti ---> amod adjectival modifier
# - ---> amod adjectival modifier
# bullying ---> amod adjectival modifier
# laws ---> pobj object of preposition
# . ---> punct punctuation
# Justice ---> compound compound
# Kagan ---> nsubj nominal subject
# posited ---> ROOT None
# an ---> det determiner
# off ---> amod adjectival modifier
# - ---> punct punctuation
# campus ---> compound compound
# website ---> dobj direct object
# set ---> acl clausal modifier of noun (adjectival clause)
# up ---> prt particle
# by ---> agent agent
# high ---> amod adjectival modifier
# school ---> compound compound
# boys ---> pobj object of preposition
# to ---> aux auxiliary
# rank ---> advcl adverbial clause modifier
# their ---> poss possession modifier
# female ---> amod adjectival modifier
# classmates ---> compound compound
# appearance ---> dobj direct object
# and ---> cc coordinating conjunction
# sexual ---> amod adjectival modifier
# availability ---> conj conjunct
# . ---> punct punctuation
#
#  ---> ROOT None
# All ---> nsubj nominal subject
# of ---> prep prepositional modifier
# the ---> det determiner
# justices ---> pobj object of preposition
# probed ---> ROOT None
# repeatedly ---> advmod adverbial modifier
# for ---> prep prepositional modifier
# workable ---> amod adjectival modifier
# standard ---> pobj object of preposition
# to ---> aux auxiliary
# adopt ---> acl clausal modifier of noun (adjectival clause)
# — ---> punct punctuation
# a ---> det determiner
# rule ---> dobj direct object
# that ---> nsubj nominal subject
# would ---> aux auxiliary
# guide ---> relcl relative clause modifier
# schools ---> dobj direct object
# as ---> prep prepositional modifier
# to ---> prep prepositional modifier
# how ---> advmod adverbial modifier
# to ---> aux auxiliary
# handle ---> pcomp complement of preposition
# these ---> det determiner
# tricky ---> amod adjectival modifier
# questions ---> dobj direct object
# . ---> punct punctuation
# Cole ---> nsubj nominal subject
# said ---> ROOT None
# student ---> compound compound
# speech ---> nsubjpass nominal subject (passive)
# should ---> aux auxiliary
# be ---> auxpass auxiliary (passive)
# protected ---> ccomp clausal complement
# online ---> advmod adverbial modifier
# . ---> punct punctuation
#
#  ---> ROOT None
# " ---> punct punctuation
# Outside ---> advmod adverbial modifier
# of ---> prep prepositional modifier
# school ---> pobj object of preposition
# , ---> punct punctuation
# the ---> det determiner
# priority ---> nsubj nominal subject
# is ---> ccomp clausal complement
# not ---> neg negation modifier
# to ---> aux auxiliary
# give ---> xcomp open clausal complement
# the ---> det determiner
# school ---> compound compound
# discretion ---> dobj direct object
# to ---> aux auxiliary
# regulate ---> advcl adverbial clause modifier
# kids ---> poss possession modifier
# ' ---> case case marking
# speech ---> dobj direct object
# , ---> punct punctuation
# " ---> punct punctuation
# he ---> nsubj nominal subject
# said ---> ROOT None
# . ---> punct punctuation
# But ---> cc coordinating conjunction
# the ---> det determiner
# school ---> compound compound
# district ---> poss possession modifier
# 's ---> case case marking
# lawyer ---> meta meta modifier
# , ---> punct punctuation
# Lisa ---> compound compound
# Blatt ---> nsubj nominal subject
# said ---> ROOT None
# that ---> mark marker
# standard ---> nsubj nominal subject
# would ---> aux auxiliary
# be ---> ccomp clausal complement
# a ---> det determiner
# " ---> punct punctuation
# nightmare ---> attr attribute
# . ---> punct punctuation
# " ---> punct punctuation
# It ---> nsubj nominal subject
# would ---> aux auxiliary
# , ---> punct punctuation
# she ---> nsubj nominal subject
# said ---> parataxis parataxis
# , ---> punct punctuation
# mean ---> ROOT None
# " ---> punct punctuation
# open ---> amod adjectival modifier
# season ---> dobj direct object
# " ---> punct punctuation
# on ---> prep prepositional modifier
# schools ---> pobj object of preposition
# and ---> cc coordinating conjunction
# produce ---> conj conjunct
# " ---> punct punctuation
# chaos ---> dobj direct object
# " ---> punct punctuation
# in ---> prep prepositional modifier
# the ---> det determiner
# lower ---> amod adjectival modifier
# courts ---> pobj object of preposition
# . ---> punct punctuation

# %% [markdown]
# # Lemmatization

# %%
for token in doc:
    print (token.text, '--->', token.lemma_, spacy.explain(token.lemma_))
# Out:
# Brandi ---> Brandi None
# Levy ---> Levy None
# wears ---> wear None
# her ---> her None
# former ---> former None
# cheerleading ---> cheerleading None
# outfit ---> outfit None
# as ---> as None
# she ---> she None
# looks ---> look None
# at ---> at None
# her ---> her None
# mobile ---> mobile None
# phone ---> phone None
# while ---> while None
# sitting ---> sit None
# outside ---> outside None
# Mahanoy ---> Mahanoy None
# Area ---> Area None
# High ---> High None
# School ---> School None
# in ---> in None
# Mahanoy ---> Mahanoy None
# City ---> City None
# , ---> , punctuation mark, comma
# Pa. ---> Pa. None
# , ---> , punctuation mark, comma
# on ---> on None
# April ---> April None
# 4.Facing ---> 4.facing None
# its ---> its None
# biggest ---> big None
# student ---> student None
# speech ---> speech None
# case ---> case case marking
# in ---> in None
# a ---> a None
# half ---> half None
# - ---> - None
# century ---> century None
# , ---> , punctuation mark, comma
# the ---> the None
# Supreme ---> Supreme None
# Court ---> Court None
# seemed ---> seem None
# to ---> to None
# be ---> be None
# looking ---> look None
# for ---> for None
# a ---> a None
# narrow ---> narrow None
# exit ---> exit None
# door ---> door None
# on ---> on None
# Wednesday ---> Wednesday None
# . ---> . punctuation mark, sentence closer
# At ---> at None
# issue ---> issue None
# was ---> be None
# whether ---> whether None
# schools ---> school None
# may ---> may None
# punish ---> punish None
# students ---> student None
# for ---> for None
# speech ---> speech None
# that ---> that None
# occurs ---> occur None
# online ---> online None
# and ---> and None
# off ---> off None
# - ---> - None
# campus ---> campus None
# but ---> but None
# that ---> that None
# may ---> may None
# affect ---> affect None
# school ---> school None
# order ---> order None
# . ---> . punctuation mark, sentence closer
# The ---> the None
# case ---> case case marking
# has ---> have None
# been ---> be None
# billed ---> bill None
# as ---> as None
# the ---> the None
# most ---> most None
# important ---> important None
# student ---> student None
# speech ---> speech None
# case ---> case case marking
# since ---> since None
# 1969 ---> 1969 None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# That ---> that None
# landmark ---> landmark None
# ruling ---> ruling None
# came ---> come None
# at ---> at None
# the ---> the None
# height ---> height None
# of ---> of None
# the ---> the None
# Vietnam ---> Vietnam None
# War ---> War None
# . ---> . punctuation mark, sentence closer
# Mary ---> Mary None
# Beth ---> Beth None
# Tinker ---> Tinker None
# and ---> and None
# four ---> four None
# other ---> other None
# students ---> student None
# went ---> go None
# to ---> to None
# court ---> court None
# after ---> after None
# they ---> they None
# were ---> be None
# suspended ---> suspend None
# for ---> for None
# wearing ---> wear None
# black ---> black None
# armbands ---> armband None
# to ---> to None
# school ---> school None
# to ---> to None
# protest ---> protest None
# the ---> the None
# war ---> war None
# . ---> . punctuation mark, sentence closer
# By ---> by None
# a ---> a None
# vote ---> vote None
# of ---> of None
# 7 ---> 7 None
# to ---> to None
# 2 ---> 2 None
# , ---> , punctuation mark, comma
# the ---> the None
# high ---> high None
# court ---> court None
# ruled ---> rule None
# at ---> at None
# the ---> the None
# time ---> time None
# for ---> for None
# the ---> the None
# first ---> first None
# time ---> time None
# that ---> that None
# kids ---> kid None
# do ---> do None
# have ---> have None
# First ---> First None
# Amendment ---> Amendment None
# free ---> free None
# speech ---> speech None
# rights ---> right None
# at ---> at None
# school ---> school None
# , ---> , punctuation mark, comma
# unless ---> unless None
# school ---> school None
# officials ---> official None
# reasonably ---> reasonably None
# forecast ---> forecast None
# it ---> it None
# will ---> will None
# cause ---> cause None
# disruptions ---> disruption None
# . ---> . punctuation mark, sentence closer
# Wednesday ---> Wednesday None
# 's ---> 's None
# case ---> case case marking
# did ---> do None
# not ---> not None
# involve ---> involve None
# such ---> such None
# serious ---> serious None
# speech ---> speech None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# And ---> and None
# on ---> on None
# Wednesday ---> Wednesday None
# , ---> , punctuation mark, comma
# the ---> the None
# Supreme ---> Supreme None
# Court ---> Court None
# faced ---> face None
# a ---> a None
# question ---> question None
# that ---> that None
# did ---> do None
# not ---> not None
# exist ---> exist None
# in ---> in None
# 1969 ---> 1969 None
# : ---> : punctuation mark, colon or ellipsis
# Can ---> can None
# schools ---> school None
# punish ---> punish None
# students ---> student None
# for ---> for None
# their ---> their None
# online ---> online None
# but ---> but None
# off ---> off None
# - ---> - None
# campus ---> campus None
# speech?Justice ---> speech?justice None
# Stephen ---> Stephen None
# Breyer ---> Breyer None
# got ---> get None
# to ---> to None
# the ---> the None
# heart ---> heart None
# of ---> of None
# the ---> the None
# matter ---> matter None
# quickly ---> quickly None
# , ---> , punctuation mark, comma
# wondering ---> wonder None
# whether ---> whether None
# online ---> online None
# swearing ---> swear None
# off ---> off None
# - ---> - None
# campus ---> campus None
# should ---> should None
# even ---> even None
# qualify ---> qualify None
# for ---> for None
# school ---> school None
# punishment ---> punishment None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# " ---> " None
# If ---> if None
# swearing ---> swear None
# off ---> off None
# - ---> - None
# campus ---> campus None
# did ---> do None
# [ ---> [ None
# qualify ---> qualify None
# ] ---> ] None
# , ---> , punctuation mark, comma
# my ---> my None
# goodness ---> goodness None
# , ---> , punctuation mark, comma
# every ---> every None
# school ---> school None
# in ---> in None
# the ---> the None
# country ---> country None
# would ---> would None
# be ---> be None
# doing ---> do None
# nothing ---> nothing None
# but ---> but None
# punishing ---> punish None
# , ---> , punctuation mark, comma
# " ---> " None
# he ---> he None
# said ---> say None
# . ---> . punctuation mark, sentence closer
# Justice ---> Justice None
# Sonia ---> Sonia None
# Sotomayor ---> Sotomayor None
# chimed ---> chime None
# in ---> in None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# " ---> " None
# Kids ---> kid None
# basically ---> basically None
# talk ---> talk None
# to ---> to None
# classmates ---> classmate None
# , ---> , punctuation mark, comma
# most ---> most None
# of ---> of None
# their ---> their None
# exchanges ---> exchange None
# have ---> have None
# to ---> to None
# do ---> do None
# with ---> with None
# their ---> their None
# perceptions ---> perception None
# of ---> of None
# the ---> the None
# authoritarian ---> authoritarian None
# nature ---> nature None
# of ---> of None
# their ---> their None
# teachers ---> teacher None
# and ---> and None
# others ---> other None
# . ---> . punctuation mark, sentence closer
# "Justice ---> "justice None
# Brett ---> Brett None
# Kavanaugh ---> Kavanaugh None
# , ---> , punctuation mark, comma
# who ---> who None
# coaches ---> coach None
# his ---> his None
# daughters ---> daughter None
# ' ---> ' None
# sports ---> sport None
# teams ---> team None
# , ---> , punctuation mark, comma
# seemed ---> seem None
# to ---> to None
# understand ---> understand None
# Brandi ---> Brandi None
# 's ---> 's None
# frustration ---> frustration None
# , ---> , punctuation mark, comma
# acknowledging ---> acknowledge None
# that ---> that None
# even ---> even None
# NBA ---> NBA None
# legend ---> legend None
# Michael ---> Michael None
# Jordan ---> Jordan None
# had ---> have None
# sore ---> sore None
# feelings ---> feeling None
# more ---> more None
# than ---> than None
# 40 ---> 40 None
# years ---> year None
# after ---> after None
# not ---> not None
# making ---> make None
# the ---> the None
# varsity ---> varsity None
# team ---> team None
# in ---> in None
# high ---> high None
# school ---> school None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# Siding ---> side None
# with ---> with None
# the ---> the None
# Mahanoy ---> Mahanoy None
# school ---> school None
# district ---> district None
# in ---> in None
# the ---> the None
# case ---> case case marking
# , ---> , punctuation mark, comma
# the ---> the None
# Justice ---> Justice None
# Department ---> Department None
# argued ---> argue None
# that ---> that None
# schools ---> school None
# could ---> could None
# regulate ---> regulate None
# off ---> off None
# - ---> - None
# campus ---> campus None
# speech ---> speech None
# only ---> only None
# if ---> if None
# it ---> it None
# is ---> be None
# related ---> relate None
# to ---> to None
# school ---> school None
# matters ---> matter None
# and ---> and None
# could ---> could None
# cause ---> cause None
# a ---> a None
# " ---> " None
# substantial ---> substantial None
# disruption ---> disruption None
# . ---> . punctuation mark, sentence closer
# ""That ---> ""that None
# means ---> mean None
# really ---> really None
# everything ---> everything None
# that ---> that None
# mentions ---> mention None
# a ---> a None
# school ---> school None
# at ---> at None
# all ---> all None
# is ---> be None
# school ---> school None
# speech ---> speech None
# , ---> , punctuation mark, comma
# right ---> right None
# ? ---> ? None
# " ---> " None
# asked ---> ask None
# a ---> a None
# skeptical ---> skeptical None
# Justice ---> Justice None
# Elena ---> Elena None
# Kagan ---> Kagan None
# . ---> . punctuation mark, sentence closer
# Deputy ---> Deputy None
# Solicitor ---> Solicitor None
# General ---> General None
# Malcolm ---> Malcolm None
# Stewart ---> Stewart None
# tried ---> try None
# to ---> to None
# offer ---> offer None
# a ---> a None
# nuanced ---> nuance None
# distinction ---> distinction None
# , ---> , punctuation mark, comma
# but ---> but None
# Kagan ---> Kagan None
# was ---> be None
# having ---> have None
# none ---> none None
# of ---> of None
# it ---> it None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# Cutting ---> cut None
# right ---> right None
# to ---> to None
# the ---> the None
# question ---> question None
# of ---> of None
# which ---> which None
# speech ---> speech None
# is ---> be None
# punishable ---> punishable None
# , ---> , punctuation mark, comma
# she ---> she None
# asked ---> ask None
# , ---> , punctuation mark, comma
# " ---> " None
# Can ---> can None
# I ---> I None
# give ---> give None
# you ---> you None
# a ---> a None
# few ---> few None
# hypotheticals ---> hypothetical None
# , ---> , punctuation mark, comma
# and ---> and None
# you ---> you None
# just ---> just None
# tell ---> tell None
# me ---> I None
# school ---> school None
# speech ---> speech None
# or ---> or None
# not ---> not None
# school ---> school None
# speech?"Each ---> speech?"each None
# of ---> of None
# these ---> these None
# , ---> , punctuation mark, comma
# conceded ---> concede None
# Stewart ---> Stewart None
# , ---> , punctuation mark, comma
# would ---> would None
# be ---> be None
# considered ---> consider None
# school ---> school None
# speech ---> speech None
# under ---> under None
# the ---> the None
# standard ---> standard None
# proposed ---> propose None
# by ---> by None
# the ---> the None
# Justice ---> Justice None
# Department ---> Department None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# In ---> in None
# other ---> other None
# words ---> word None
# , ---> , punctuation mark, comma
# all ---> all None
# of ---> of None
# these ---> these None
# messages ---> message None
# sent ---> send None
# from ---> from None
# off ---> off None
# campus ---> campus None
# might ---> might None
# well ---> well None
# be ---> be None
# punishable ---> punishable None
# school ---> school None
# speech ---> speech None
# . ---> . punctuation mark, sentence closer
# The ---> the None
# ACLU ---> ACLU None
# 's ---> 's None
# David ---> David None
# Cole ---> Cole None
# , ---> , punctuation mark, comma
# representing ---> represent None
# Brandi ---> Brandi None
# Levy ---> Levy None
# , ---> , punctuation mark, comma
# said ---> say None
# that ---> that None
# once ---> once None
# schools ---> school None
# can ---> can None
# discipline ---> discipline None
# students ---> student None
# for ---> for None
# off ---> off None
# - ---> - None
# campus ---> campus None
# speech ---> speech None
# , ---> , punctuation mark, comma
# that ---> that None
# would ---> would None
# dramatically ---> dramatically None
# expand ---> expand None
# the ---> the None
# disciplinary ---> disciplinary None
# reach ---> reach None
# of ---> of None
# schools ---> school None
# set ---> set None
# out ---> out None
# by ---> by None
# the ---> the None
# court ---> court None
# in ---> in None
# the ---> the None
# Tinker ---> Tinker None
# case ---> case case marking
# in ---> in None
# 1969."Expanding ---> 1969."expande None
# Tinker ---> Tinker None
# would ---> would None
# transform ---> transform None
# a ---> a None
# limited ---> limited None
# exception ---> exception None
# into ---> into None
# a ---> a None
# 24/7 ---> 24/7 None
# rule ---> rule None
# that ---> that None
# would ---> would None
# upend ---> upend None
# the ---> the None
# First ---> First None
# Amendment ---> Amendment None
# 's ---> 's None
# bedrock ---> bedrock None
# principle ---> principle None
# , ---> , punctuation mark, comma
# " ---> " None
# argued ---> argue None
# Cole ---> Cole None
# , ---> , punctuation mark, comma
# " ---> " None
# and ---> and None
# would ---> would None
# require ---> require None
# students ---> student None
# to ---> to None
# effectively ---> effectively None
# carry ---> carry None
# the ---> the None
# schoolhouse ---> schoolhouse None
# on ---> on None
# their ---> their None
# backs ---> back None
# in ---> in None
# terms ---> term None
# of ---> of None
# speech ---> speech None
# rights ---> right None
# everywhere ---> everywhere None
# they ---> they None
# go ---> go None
# . ---> . punctuation mark, sentence closer
# "But ---> "but None
# , ---> , punctuation mark, comma
# the ---> the None
# justices ---> justice None
# wanted ---> want None
# to ---> to None
# know ---> know None
# , ---> , punctuation mark, comma
# what ---> what None
# about ---> about None
# cases ---> case case marking
# of ---> of None
# harassment ---> harassment None
# and ---> and None
# bullying ---> bullying None
# ? ---> ? None
#
#  --->
#  None
# After ---> after None
# all ---> all None
# , ---> , punctuation mark, comma
# some ---> some None
# 47 ---> 47 None
# states ---> state None
# require ---> require None
# enforcement ---> enforcement None
# of ---> of None
# anti ---> anti None
# - ---> - None
# bullying ---> bullying None
# laws ---> law None
# . ---> . punctuation mark, sentence closer
# Justice ---> Justice None
# Kagan ---> Kagan None
# posited ---> posit None
# an ---> an None
# off ---> off None
# - ---> - None
# campus ---> campus None
# website ---> website None
# set ---> set None
# up ---> up None
# by ---> by None
# high ---> high None
# school ---> school None
# boys ---> boy None
# to ---> to None
# rank ---> rank None
# their ---> their None
# female ---> female None
# classmates ---> classmate None
# appearance ---> appearance None
# and ---> and None
# sexual ---> sexual None
# availability ---> availability None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# All ---> all None
# of ---> of None
# the ---> the None
# justices ---> justice None
# probed ---> probe None
# repeatedly ---> repeatedly None
# for ---> for None
# workable ---> workable None
# standard ---> standard None
# to ---> to None
# adopt ---> adopt None
# — ---> — None
# a ---> a None
# rule ---> rule None
# that ---> that None
# would ---> would None
# guide ---> guide None
# schools ---> school None
# as ---> as None
# to ---> to None
# how ---> how None
# to ---> to None
# handle ---> handle None
# these ---> these None
# tricky ---> tricky None
# questions ---> question None
# . ---> . punctuation mark, sentence closer
# Cole ---> Cole None
# said ---> say None
# student ---> student None
# speech ---> speech None
# should ---> should None
# be ---> be None
# protected ---> protect None
# online ---> online None
# . ---> . punctuation mark, sentence closer
#
#  --->
#  None
# " ---> " None
# Outside ---> outside None
# of ---> of None
# school ---> school None
# , ---> , punctuation mark, comma
# the ---> the None
# priority ---> priority None
# is ---> be None
# not ---> not None
# to ---> to None
# give ---> give None
# the ---> the None
# school ---> school None
# discretion ---> discretion None
# to ---> to None
# regulate ---> regulate None
# kids ---> kid None
# ' ---> ' None
# speech ---> speech None
# , ---> , punctuation mark, comma
# " ---> " None
# he ---> he None
# said ---> say None
# . ---> . punctuation mark, sentence closer
# But ---> but None
# the ---> the None
# school ---> school None
# district ---> district None
# 's ---> 's None
# lawyer ---> lawyer None
# , ---> , punctuation mark, comma
# Lisa ---> Lisa None
# Blatt ---> Blatt None
# said ---> say None
# that ---> that None
# standard ---> standard None
# would ---> would None
# be ---> be None
# a ---> a None
# " ---> " None
# nightmare ---> nightmare None
# . ---> . punctuation mark, sentence closer
# " ---> " None
# It ---> it None
# would ---> would None
# , ---> , punctuation mark, comma
# she ---> she None
# said ---> say None
# , ---> , punctuation mark, comma
# mean ---> mean None
# " ---> " None
# open ---> open None
# season ---> season None
# " ---> " None
# on ---> on None
# schools ---> school None
# and ---> and None
# produce ---> produce None
# " ---> " None
# chaos ---> chaos None
# " ---> " None
# in ---> in None
# the ---> the None
# lower ---> low None
# courts ---> court None
# . ---> . punctuation mark, sentence closer

# %% [markdown]
# # Sentence Boundary Detection

# %%
doc.sents

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print (sentence)
# Out:
# Brandi Levy wears her former cheerleading outfit as she looks at her mobile phone while sitting outside Mahanoy Area High School in Mahanoy City, Pa., on April 4.Facing its biggest student speech case in a half-century, the Supreme Court seemed to be looking for a narrow exit door on Wednesday.
# At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.
# The case has been billed as the most important student speech case since 1969.
#
#
# That landmark ruling came at the height of the Vietnam War.
# Mary Beth Tinker and four other students went to court after they were suspended for wearing black armbands to school to protest the war.
# By a vote of 7 to 2, the high court ruled at the time for the first time that kids do have First Amendment free speech rights at school, unless school officials reasonably forecast it will cause disruptions.
# Wednesday's case did not involve such serious speech.
#
#
# And on Wednesday, the Supreme Court faced a question that did not exist in 1969: Can schools punish students for their online but off-campus speech?Justice Stephen Breyer got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.
#
# "If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing," he said.
# Justice Sonia Sotomayor chimed in.
#
# "Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others.
# "Justice Brett Kavanaugh, who coaches his daughters' sports teams, seemed to understand Brandi's frustration, acknowledging that even NBA legend Michael Jordan had sore feelings more than 40 years after not making the varsity team in high school.
#
#
# Siding with the Mahanoy school district in the case, the Justice Department argued that schools could regulate off-campus speech only if it is related to school matters and could cause a "substantial disruption.
# ""That means really everything that mentions a school at all is school speech, right?" asked a skeptical Justice Elena Kagan.
# Deputy Solicitor General Malcolm Stewart tried to offer a nuanced distinction, but Kagan was having none of it.
#
# Cutting right to the question of which speech is punishable, she asked, "Can I give you a few hypotheticals, and you just tell me school speech or not school speech?"Each of these, conceded Stewart, would be considered school speech under the standard proposed by the Justice Department.
#
#
# In other words, all of these messages sent from off campus might well be punishable school speech.
# The ACLU's David Cole, representing Brandi Levy, said that once schools can discipline students for off-campus speech, that would dramatically expand the disciplinary reach of schools set out by the court in the Tinker case in 1969."Expanding Tinker would transform a limited exception into a 24/7 rule that would upend the First Amendment's bedrock principle," argued Cole, "and would require students to effectively carry the schoolhouse on their backs in terms of speech rights everywhere they go.
# "But, the justices wanted to know, what about cases of harassment and bullying?
#
# After all, some 47 states require enforcement of anti-bullying laws.
# Justice Kagan posited an off-campus website set up by high school boys to rank their female classmates appearance and sexual availability.
#
#
# All of the justices probed repeatedly for workable standard to adopt — a rule that would guide schools as to how to handle these tricky questions.
# Cole said student speech should be protected online.
#
#
# "Outside of school, the priority is not to give the school discretion to regulate kids' speech," he said.
# But the school district's lawyer, Lisa Blatt said that standard would be a "nightmare.
# " It would, she said, mean "open season" on schools and produce "chaos" in the lower courts.

# %% [markdown]
# # Named Entity

# %%
for ent in doc.ents:
    print(ent.text, '--->', ent.label_, '--->', spacy.explain(ent.label_))
# Out:
# Brandi Levy ---> PERSON ---> People, including fictional
# Mahanoy Area High School ---> ORG ---> Companies, agencies, institutions, etc.
# Mahanoy City ---> GPE ---> Countries, cities, states
# Pa. ---> GPE ---> Countries, cities, states
# April 4.Facing ---> DATE ---> Absolute or relative dates or periods
# a half-century ---> DATE ---> Absolute or relative dates or periods
# the Supreme Court ---> ORG ---> Companies, agencies, institutions, etc.
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# 1969 ---> DATE ---> Absolute or relative dates or periods
# the Vietnam War ---> EVENT ---> Named hurricanes, battles, wars, sports events, etc.
# Mary Beth Tinker ---> PERSON ---> People, including fictional
# four ---> CARDINAL ---> Numerals that do not fall under another type
# 7 to 2 ---> CARDINAL ---> Numerals that do not fall under another type
# first ---> ORDINAL ---> "first", "second", etc.
# First Amendment ---> LAW ---> Named documents made into laws.
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# the Supreme Court ---> ORG ---> Companies, agencies, institutions, etc.
# 1969 ---> DATE ---> Absolute or relative dates or periods
# Stephen Breyer ---> PERSON ---> People, including fictional
# Sonia Sotomayor ---> PERSON ---> People, including fictional
# Brett Kavanaugh ---> PERSON ---> People, including fictional
# Brandi ---> ORG ---> Companies, agencies, institutions, etc.
# NBA ---> ORG ---> Companies, agencies, institutions, etc.
# Michael Jordan ---> PERSON ---> People, including fictional
# more than 40 years ---> DATE ---> Absolute or relative dates or periods
# the Justice Department ---> ORG ---> Companies, agencies, institutions, etc.
# Elena Kagan ---> PERSON ---> People, including fictional
# Malcolm Stewart ---> PERSON ---> People, including fictional
# Kagan ---> PERSON ---> People, including fictional
# Stewart ---> PERSON ---> People, including fictional
# the Justice Department ---> ORG ---> Companies, agencies, institutions, etc.
# ACLU ---> ORG ---> Companies, agencies, institutions, etc.
# David Cole ---> PERSON ---> People, including fictional
# Brandi Levy ---> PERSON ---> People, including fictional
# Tinker ---> PRODUCT ---> Objects, vehicles, foods, etc. (not services)
# 1969."Expanding ---> DATE ---> Absolute or relative dates or periods
# Tinker ---> ORG ---> Companies, agencies, institutions, etc.
# 24/7 ---> CARDINAL ---> Numerals that do not fall under another type
# the First Amendment's ---> LAW ---> Named documents made into laws.
# Cole ---> PRODUCT ---> Objects, vehicles, foods, etc. (not services)
# 47 ---> CARDINAL ---> Numerals that do not fall under another type
# Kagan ---> PERSON ---> People, including fictional
# Cole ---> PRODUCT ---> Objects, vehicles, foods, etc. (not services)
# Lisa Blatt ---> PERSON ---> People, including fictional

# %% [markdown]
# # Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brandi Levy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wears her former cheerleading outfit as she looks at her mobile phone while sitting outside
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mahanoy Area High School
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mahanoy City
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pa.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 4.Facing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  its biggest student speech case in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a half-century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  seemed to be looking for a narrow exit door on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .At issue was whether schools may punish students for speech that occurs online and off-campus but that may affect school order.The case has been billed as the most important student speech case since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>That landmark ruling came at the height of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Vietnam War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mary Beth Tinker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  other students went to court after they were suspended for wearing black armbands to school to protest the war.By a vote of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7 to 2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , the high court ruled at the time for the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  time that kids do have
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First Amendment
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  free speech rights at school, unless school officials reasonably forecast it will cause disruptions.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 's case did not involve such serious speech.</br>And on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  faced a question that did not exist in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1969
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# : Can schools punish students for their online but off-campus speech?Justice
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stephen Breyer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  got to the heart of the matter quickly, wondering whether online swearing off-campus should even qualify for school punishment.</br>&quot;If swearing off-campus did [qualify], my goodness, every school in the country would be doing nothing but punishing,&quot; he said.Justice
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sonia Sotomayor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  chimed in.</br>&quot;Kids basically talk to classmates, most of their exchanges have to do with their perceptions of the authoritarian nature of their teachers and others.&quot;Justice
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0

# %% [markdown]
# # Dependency Parsing

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7d4339caf85e4997b4ff7b779db70e45-0" class="displacy" width="115375" height="1799.5" direction="ltr" style="max-width: none; height: 1799.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Brandi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Levy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">wears</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">former</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">cheerleading</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">outfit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">looks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">mobile</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">phone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">while</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">sitting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">outside</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Mahanoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Area</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">High</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">School</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Mahanoy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">City,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Pa.,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">April</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">4.Facing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">biggest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1709.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">student</tspan>
#     <

# %% [markdown]
# # Putting it all together

# %%
lis = []

# %%
for token in doc:
    dic ={}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explanation']= spacy.explain(token.tag_)
    lis.append(dic)

# %%
import pandas as pd

# %%
data = pd.DataFrame(lis)

# %%
data
# Out:
#       Token    POS  Tags       Dep                                Explanation
# 0    Brandi  PROPN   NNP  compound                      noun, proper singular
# 1      Levy  PROPN   NNP     nsubj                      noun, proper singular
# 2     wears   VERB   VBZ      ROOT          verb, 3rd person singular present
# 3       her   PRON  PRP$      poss                        pronoun, possessive
# 4    former    ADJ    JJ      amod                                  adjective
# ..      ...    ...   ...       ...                                        ...
# 748      in    ADP    IN      prep  conjunction, subordinating or preposition
# 749     the    DET    DT       det                                 determiner
# 750   lower    ADJ   JJR      amod                     adjective, comparative
# 751  courts   NOUN   NNS      pobj                               noun, plural
# 752       .  PUNCT     .     punct          punctuation mark, sentence closer
#
# [753 rows x 5 columns]

# %%
data.to_csv('nlptasks1.csv', index = False)

# %%
l = []
for ent in doc.ents:
    d = {}
    d['Entities'] = ent.text
    d['Labels'] = ent.label_
    d['Explanation'] = spacy.explain(ent.label_)
    l.append(d)

# %%
entities = pd.DataFrame(l)

# %%
entities
# Out:
#                     Entities    Labels  \
# 0                Brandi Levy    PERSON
# 1   Mahanoy Area High School       ORG
# 2               Mahanoy City       GPE
# 3                        Pa.       GPE
# 4             April 4.Facing      DATE
# 5             a half-century      DATE
# 6          the Supreme Court       ORG
# 7                  Wednesday      DATE
# 8                       1969      DATE
# 9            the Vietnam War     EVENT
# 10          Mary Beth Tinker    PERSON
# 11                      four  CARDINAL
# 12                    7 to 2  CARDINAL
# 13                     first   ORDINAL
# 14           First Amendment       LAW
# 15                 Wednesday      DATE
# 16                 Wednesday      DATE
# 17         the Supreme Court       ORG
# 18                      1969      DATE
# 19            Stephen Breyer    PERSON
# 20           Sonia Sotomayor    PERSON
# 21           Brett Kavanaugh    PERSON
# 22                    Brandi       ORG
# 23                       NBA       ORG
# 24            Michael Jordan    PERSON
# 25        more than 40 years      DATE
# 26    the Justice Department       ORG
# 27               Elena Kagan    PERSON
# 28           Malcolm Stewart    PERSON
# 29                     Kagan    PERSON
# 30                   Stewart    PERSON
# 31    the Justice Department       ORG
# 32                      ACLU       ORG
# 33                David Cole    PERSON
# 34               Brandi Levy    PERSON
# 35                    Tinker   PRODUCT
# 36           1969."Expanding      DATE
# 37                    Tinker       ORG
# 38                      24/7  CARDINAL
# 39     the First Amendment's       LAW
# 40                      Cole   PRODUCT
# 41                        47  CARDINAL
# 42                     Kagan    PERSON
# 43                      Cole   PRODUCT
# 44                Lisa Blatt    PERSON
#
#                                           Explanation
# 0                         People, including fictional
# 1             Companies, agencies, institutions, etc.
# 2                           Countries, cities, states
# 3                           Countries, cities, states
# 4               Absolute or relative dates or periods
# 5               Absolute or relative dates or periods
# 6             Companies, agencies, institutions, etc.
# 7               Absolute or relative dates or periods
# 8               Absolute or relative dates or periods
# 9   Named hurricanes, battles, wars, sports events...
# 10                        People, including fictional
# 11       Numerals that do not fall under another type
# 12       Numerals that do not fall under another type
# 13                            "first", "second", etc.
# 14                    Named documents made into laws.
# 15              Absolute or relative dates or periods
# 16              Absolute or relative dates or periods
# 17            Companies, agencies, institutions, etc.
# 18              Absolute or relative dates or periods
# 19                        People, including fictional
# 20                        People, including fictional
# 21                        People, including fictional
# 22            Companies, agencies, institutions, etc.
# 23            Companies, agencies, institutions, etc.
# 24                        People, including fictional
# 25              Absolute or relative dates or periods
# 26            Companies, agencies, institutions, etc.
# 27                        People, including fictional
# 28                        People, including fictional
# 29                        People, including fictional
# 30                        People, including fictional
# 31            Companies, agencies, institutions, etc.
# 32            Companies, agencies, institutions, etc.
# 33                        People, including fictional
# 34                        People, including fictional
# 35      Objects, vehicles, foods, etc. (not services)
# 36              Absolute or relative dates or periods
# 37            Companies, agencies, institutions, etc.
# 38       Numerals that do not fall under another type
# 39                    Named documents made into laws.
# 40      Objects, vehicles, foods, etc. (not services)
# 41       Numerals that do not fall under another type
# 42                        People, including fictional
# 43      Objects, vehicles, foods, etc. (not services)
# 44                        People, including fictional

# %%
entities.to_csv('nlptasks2.csv', index = False)
